# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架提取后的图片数据集载入，划分训练集测试集'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited55/train/downdog'
test_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited55/test/downdog'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset = data1+data2+data3+data4+data5+data6+data7+data8
testset = torchvision.datasets.ImageFolder(root=test_path,transform=transform1) 
print(data1.class_to_idx)
BATCH_SIZE = 128
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# {'nonstandard': 0, 'standard': 1}

# %%
'''VGG19网络'''
import torchvision.models as models
import torch.nn as nn
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier[6] = nn.Linear(in_features=4096, out_features=2, bias=True)
'''for i in range(1,4):
  vgg19.classifier[i] = nn.Sequential()'''
print(vgg19)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 271MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split2.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split2.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split2.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split2.csv',index=False)

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(vgg19.to(device))
# Out:
# 测试集精度为：50%
# 测试集中不标准动作图片的预测精度为：52%
# 测试集中标准动作图片的预测精度为：48%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     28   25
# 1.0     34   32

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(vgg19.to(device),50,2)
# Out:
# [1,    2] loss:107.061
# [1,    4] loss:106.222
# [1,    6] loss:102.782
# [1,    8] loss:64.345
# Test set: Average loss: 0.7983
# [2,    2] loss:102.772
# [2,    4] loss:102.530
# [2,    6] loss:105.285
# [2,    8] loss:70.437
# Test set: Average loss: 0.7840
# [3,    2] loss:99.820
# [3,    4] loss:92.729
# [3,    6] loss:91.760
# [3,    8] loss:60.136
# Test set: Average loss: 0.6786
# [4,    2] loss:90.735
# [4,    4] loss:85.075
# [4,    6] loss:92.514
# [4,    8] loss:59.059
# Test set: Average loss: 0.5979
# [5,    2] loss:89.646
# [5,    4] loss:89.430
# [5,    6] loss:91.653
# [5,    8] loss:60.718
# Test set: Average loss: 0.6996
# [6,    2] loss:86.630
# [6,    4] loss:84.587
# [6,    6] loss:90.671
# [6,    8] loss:60.627
# Test set: Average loss: 0.6794
# [7,    2] loss:86.916
# [7,    4] loss:82.624
# [7,    6] loss:88.321
# [7,    8] loss:57.996
# Test set: Average loss: 0.7135
# [8,    2] loss:86.335
# [8,    4] loss:85.093
# [8,    6] loss:87.044
# [8,    8] loss:57.653
# Test set: Average loss: 0.6710
# [9,    2] loss:86.825
# [9,    4] loss:84.247
# [9,    6] loss:87.973
# [9,    8] loss:54.491
# Test set: Average loss: 0.6945
# [10,    2] loss:79.964
# [10,    4] loss:83.528
# [10,    6] loss:83.284
# [10,    8] loss:54.923
# Test set: Average loss: 0.6901
# [11,    2] loss:88.170
# [11,    4] loss:78.805
# [11,    6] loss:83.661
# [11,    8] loss:52.314
# Test set: Average loss: 0.6293
# [12,    2] loss:79.577
# [12,    4] loss:83.236
# [12,    6] loss:80.294
# [12,    8] loss:49.544
# Test set: Average loss: 0.6220
# [13,    2] loss:80.861
# [13,    4] loss:81.969
# [13,    6] loss:80.936
# [13,    8] loss:54.165
# Test set: Average loss: 0.6203
# [14,    2] loss:75.680
# [14,    4] loss:77.694
# [14,    6] loss:80.152
# [14,    8] loss:54.542
# Test set: Average loss: 0.6290
# [15,    2] loss:80.440
# [15,    4] loss:76.163
# [15,    6] loss:78.206
# [15,    8] loss:52.677
# Test set: Average loss: 0.6241
# [16,    2] loss:78.694
# [16,    4] loss:75.194
# [16,    6] loss:76.691
# [16,    8] loss:54.073
# Test set: Average loss: 0.6606
# [17,    2] loss:78.460
# [17,    4] loss:79.398
# [17,    6] loss:82.834
# [17,    8] loss:50.330
# Test set: Average loss: 0.6044
# [18,    2] loss:84.106
# [18,    4] loss:72.869
# [18,    6] loss:79.833
# [18,    8] loss:52.093
# Test set: Average loss: 0.5924
# [19,    2] loss:78.976
# [19,    4] loss:71.499
# [19,    6] loss:78.029
# [19,    8] loss:51.393
# Test set: Average loss: 0.6086
# [20,    2] loss:74.584
# [20,    4] loss:75.866
# [20,    6] loss:74.013
# [20,    8] loss:49.380
# Test set: Average loss: 0.6584
# [21,    2] loss:75.655
# [21,    4] loss:74.308
# [21,    6] loss:74.067
# [21,    8] loss:44.953
# Test set: Average loss: 0.5828
# [22,    2] loss:71.899
# [22,    4] loss:73.359
# [22,    6] loss:76.870
# [22,    8] loss:46.436
# Test set: Average loss: 0.5793
# [23,    2] loss:70.001
# [23,    4] loss:70.132
# [23,    6] loss:72.277
# [23,    8] loss:49.622
# Test set: Average loss: 0.7026
# [24,    2] loss:71.344
# [24,    4] loss:75.323
# [24,    6] loss:72.033
# [24,    8] loss:44.762
# Test set: Average loss: 0.5770
# [25,    2] loss:70.556
# [25,    4] loss:69.827
# [25,    6] loss:67.176
# [25,    8] loss:48.807
# Test set: Average loss: 0.6250
# [26,    2] loss:65.896
# [26,    4] loss:74.935
# [26,    6] loss:69.384
# [26,    8] loss:41.212
# Test set: Average loss: 0.5596
# [27,    2] loss:70.064
# [27,    4] loss:70.011
# [27,    6] loss:69.296
# [27,    8] loss:45.313
# Test set: Average loss: 0.6363
# [28,    2] loss:72.891
# [28,    4] loss:70.186
# [28,    6] loss:70.169
# [28,    8] loss:41.144
# Test set: Average loss: 0.6088
# [29,    2] loss:70.569
# [29,    4] loss:69.706
# [29,    6] loss:69.810
# [29,    8] loss:47.331
# Test set: Average loss: 0.5791
# [30,    2] loss:64.039
# [30,    4] loss:62.716
# [30,    6] loss:70.547
# [30,    8] loss:46.903
# Test set: Average loss: 0.5999
# [31,    2] loss:66.241
# [31,    4] loss:64.338
# [31,    6] loss:69.056
# [31,    8] loss:42.184
# Test set: Average loss: 0.6171
# [32,    2] loss:63.647
# [32,    4] loss:68.163
# [32,    6] loss:64.986
# [32,    8] loss:43.267
# Test set: Average loss: 0.5806
# [33,    2] loss:68.401
# [33,    4] loss:66.038
# [33,    6] loss:66.236
# [33,    8] loss:41.808
# Test set: Average loss: 0.5806
# [34,    2] loss:68.680
# [34,    4] loss:63.751
# [34,    6] loss:59.483
# [34,    8] loss:43.063
# Test set: Average loss: 0.5941
# [35,    2] loss:63.724
# [35,    4] loss:67.689
# [35,    6] loss:66.670
# [35,    8] loss:37.600
# Test set: Average loss: 0.5703
# [36,    2] loss:62.926
# [36,    4] loss:63.246
# [36,    6] loss:66.835
# [36,    8] loss:41.715
# Test set: Average loss: 0.5625
# [37,    2] loss:58.828
# [37,    4] loss:54.199
# [37,    6] loss:62.935
# [37,    8] loss:44.432
# Test set: Average loss: 0.6105
# [38,    2] loss:65.895
# [38,    4] loss:60.104
# [38,    6] loss:61.809
# [38,    8] loss:41.523
# Test set: Average loss: 0.5642
# [39,    2] loss:61.048
# [39,    4] loss:59.714
# [39,    6] loss:57.797
# [39,    8] loss:42.138
# Test set: Average loss: 0.6225
# [40,    2] loss:56.869
# [40,    4] loss:63.419
# [40,    6] loss:59.340
# [40,    8] loss:35.307
# Test set: Average loss: 0.5952
# [41,    2] loss:61.772
# [41,    4] loss:53.903
# [41,    6] loss:59.065
# [41,    8] loss:38.628
# Test set: Average loss: 0.6487
# [42,    2] loss:58.402
# [42,    4] loss:59.075
# [42,    6] loss:58.809
# [42,    8] loss:36.402
# Test set: Average loss: 0.5627
# [43,    2] loss:52.215
# [43,    4] loss:62.747
# [43,    6] loss:54.529
# [43,    8] loss:38.932
# Test set: Average loss: 0.5794
# [44,    2] loss:58.983
# [44,    4] loss:60.649
# [44,    6] loss:54.546
# [44,    8] loss:39.043
# Test set: Average loss: 0.5511
# [45,    2] loss:56.917
# [45,    4] loss:55.779
# [45,    6] loss:59.611
# [45,    8] loss:37.613
# Test set: Average loss: 0.5985
# [46,    2] loss:59.363
# [46,    4] loss:54.941
# [46,    6] loss:50.352
# [46,    8] loss:37.626
# Test set: Average loss: 0.5880
# [47,    2] loss:51.622
# [47,    4] loss:54.575
# [47,    6] loss:55.825
# [47,    8] loss:35.246
# Test set: Average loss: 0.5762
# [48,    2] loss:55.876
# [48,    4] loss:53.823
# [48,    6] loss:52.028
# [48,    8] loss:35.676
# Test set: Average loss: 0.5547
# [49,    2] loss:55.041
# [49,    4] loss:58.922
# [49,    6] loss:54.651
# [49,    8] loss:37.658
# Test set: Average loss: 0.5808
# [50,    2] loss:52.209
# [50,    4] loss:49.364
# [50,    6] loss:53.093
# [50,    8] loss:34.988
# Test set: Average loss: 0.5746
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split2.pkl')
train_test2(model.to(device),50,2)
# Out:
# [1,    2] loss:51.720
# [1,    4] loss:51.772
# [1,    6] loss:57.827
# [1,    8] loss:39.508
# Test set: Average loss: 0.6109
# [2,    2] loss:43.762
# [2,    4] loss:57.415
# [2,    6] loss:50.323
# [2,    8] loss:36.063
# Test set: Average loss: 0.6278
# [3,    2] loss:48.467
# [3,    4] loss:54.505
# [3,    6] loss:49.897
# [3,    8] loss:40.960
# Test set: Average loss: 0.5633
# [4,    2] loss:50.129
# [4,    4] loss:48.118
# [4,    6] loss:49.561
# [4,    8] loss:38.524
# Test set: Average loss: 0.6000
# [5,    2] loss:53.565
# [5,    4] loss:49.498
# [5,    6] loss:53.195
# [5,    8] loss:35.729
# Test set: Average loss: 0.5859
# [6,    2] loss:54.259
# [6,    4] loss:48.059
# [6,    6] loss:55.187
# [6,    8] loss:32.425
# Test set: Average loss: 0.6036
# [7,    2] loss:50.539
# [7,    4] loss:50.721
# [7,    6] loss:45.554
# [7,    8] loss:35.739
# Test set: Average loss: 0.5988
# [8,    2] loss:49.058
# [8,    4] loss:51.522
# [8,    6] loss:46.930
# [8,    8] loss:31.525
# Test set: Average loss: 0.5362
# [9,    2] loss:48.899
# [9,    4] loss:46.411
# [9,    6] loss:52.532
# [9,    8] loss:30.684
# Test set: Average loss: 0.5621
# [10,    2] loss:51.731
# [10,    4] loss:49.145
# [10,    6] loss:48.851
# [10,    8] loss:30.199
# Test set: Average loss: 0.5259
# [11,    2] loss:42.823
# [11,    4] loss:52.559
# [11,    6] loss:42.442
# [11,    8] loss:30.175
# Test set: Average loss: 0.5756
# [12,    2] loss:46.486
# [12,    4] loss:51.207
# [12,    6] loss:40.729
# [12,    8] loss:33.547
# Test set: Average loss: 0.5884
# [13,    2] loss:41.285
# [13,    4] loss:45.418
# [13,    6] loss:42.800
# [13,    8] loss:33.407
# Test set: Average loss: 0.5460
# [14,    2] loss:47.086
# [14,    4] loss:46.598
# [14,    6] loss:41.543
# [14,    8] loss:32.857
# Test set: Average loss: 0.5992
# [15,    2] loss:44.462
# [15,    4] loss:45.069
# [15,    6] loss:53.939
# [15,    8] loss:29.592
# Test set: Average loss: 0.5781
# [16,    2] loss:43.879
# [16,    4] loss:52.311
# [16,    6] loss:37.635
# [16,    8] loss:24.482
# Test set: Average loss: 0.6302
# [17,    2] loss:42.729
# [17,    4] loss:45.978
# [17,    6] loss:46.783
# [17,    8] loss:25.076
# Test set: Average loss: 0.5972
# [18,    2] loss:44.207
# [18,    4] loss:43.332
# [18,    6] loss:43.827
# [18,    8] loss:26.133
# Test set: Average loss: 0.5703
# [19,    2] loss:44.506
# [19,    4] loss:46.539
# [19,    6] loss:47.224
# [19,    8] loss:26.628
# Test set: Average loss: 0.5763
# [20,    2] loss:46.037
# [20,    4] loss:41.456
# [20,    6] loss:41.751
# [20,    8] loss:30.622
# Test set: Average loss: 0.5664
# [21,    2] loss:46.065
# [21,    4] loss:40.556
# [21,    6] loss:39.954
# [21,    8] loss:29.543
# Test set: Average loss: 0.6033
# [22,    2] loss:41.514
# [22,    4] loss:37.630
# [22,    6] loss:39.908
# [22,    8] loss:24.096
# Test set: Average loss: 0.5994
# [23,    2] loss:43.206
# [23,    4] loss:40.592
# [23,    6] loss:44.440
# [23,    8] loss:25.125
# Test set: Average loss: 0.6082
# [24,    2] loss:44.552
# [24,    4] loss:37.365
# [24,    6] loss:41.940
# [24,    8] loss:24.982
# Test set: Average loss: 0.5776
# [25,    2] loss:38.445
# [25,    4] loss:44.174
# [25,    6] loss:46.652
# [25,    8] loss:24.676
# Test set: Average loss: 0.6351
# [26,    2] loss:41.973
# [26,    4] loss:44.193
# [26,    6] loss:39.415
# [26,    8] loss:29.801
# Test set: Average loss: 0.6042
# [27,    2] loss:42.941
# [27,    4] loss:39.297
# [27,    6] loss:39.524
# [27,    8] loss:26.424
# Test set: Average loss: 0.6159
# [28,    2] loss:39.648
# [28,    4] loss:39.630
# [28,    6] loss:39.959
# [28,    8] loss:25.305
# Test set: Average loss: 0.6179
# [29,    2] loss:39.401
# [29,    4] loss:40.809
# [29,    6] loss:34.128
# [29,    8] loss:22.473
# Test set: Average loss: 0.6471
# [30,    2] loss:40.285
# [30,    4] loss:28.962
# [30,    6] loss:43.161
# [30,    8] loss:27.783
# Test set: Average loss: 0.5644
# [31,    2] loss:35.206
# [31,    4] loss:41.655
# [31,    6] loss:37.186
# [31,    8] loss:20.848
# Test set: Average loss: 0.6491
# [32,    2] loss:34.057
# [32,    4] loss:39.380
# [32,    6] loss:38.623
# [32,    8] loss:28.729
# Test set: Average loss: 0.6294
# [33,    2] loss:39.392
# [33,    4] loss:37.228
# [33,    6] loss:29.814
# [33,    8] loss:26.257
# Test set: Average loss: 0.6049
# [34,    2] loss:39.702
# [34,    4] loss:37.295
# [34,    6] loss:36.950
# [34,    8] loss:24.564
# Test set: Average loss: 0.6632
# [35,    2] loss:35.452
# [35,    4] loss:47.097
# [35,    6] loss:37.405
# [35,    8] loss:26.452
# Test set: Average loss: 0.6358
# [36,    2] loss:32.841
# [36,    4] loss:35.691
# [36,    6] loss:35.693
# [36,    8] loss:22.232
# Test set: Average loss: 0.6114
# [37,    2] loss:34.448
# [37,    4] loss:38.500
# [37,    6] loss:38.463
# [37,    8] loss:22.174
# Test set: Average loss: 0.6411
# [38,    2] loss:42.682
# [38,    4] loss:42.393
# [38,    6] loss:30.737
# [38,    8] loss:19.617
# Test set: Average loss: 0.6357
# [39,    2] loss:36.283
# [39,    4] loss:34.259
# [39,    6] loss:35.454
# [39,    8] loss:25.554
# Test set: Average loss: 0.5783
# [40,    2] loss:29.686
# [40,    4] loss:39.820
# [40,    6] loss:29.574
# [40,    8] loss:25.002
# Test set: Average loss: 0.5826
# [41,    2] loss:29.555
# [41,    4] loss:36.053
# [41,    6] loss:37.843
# [41,    8] loss:22.852
# Test set: Average loss: 0.5994
# [42,    2] loss:39.393
# [42,    4] loss:33.224
# [42,    6] loss:38.121
# [42,    8] loss:22.347
# Test set: Average loss: 0.6490
# [43,    2] loss:32.469
# [43,    4] loss:30.294
# [43,    6] loss:37.761
# [43,    8] loss:21.381
# Test set: Average loss: 0.6053
# [44,    2] loss:29.797
# [44,    4] loss:37.176
# [44,    6] loss:27.581
# [44,    8] loss:23.922
# Test set: Average loss: 0.6282
# [45,    2] loss:35.682
# [45,    4] loss:31.408
# [45,    6] loss:30.131
# [45,    8] loss:21.757
# Test set: Average loss: 0.5970
# [46,    2] loss:37.984
# [46,    4] loss:33.560
# [46,    6] loss:31.996
# [46,    8] loss:18.792
# Test set: Average loss: 0.6174
# [47,    2] loss:32.684
# [47,    4] loss:33.963
# [47,    6] loss:27.119
# [47,    8] loss:22.375
# Test set: Average loss: 0.6710
# [48,    2] loss:31.233
# [48,    4] loss:31.670
# [48,    6] loss:34.872
# [48,    8] loss:20.985
# Test set: Average loss: 0.6243
# [49,    2] loss:33.331
# [49,    4] loss:34.829
# [49,    6] loss:28.464
# [49,    8] loss:18.813
# Test set: Average loss: 0.5931
# [50,    2] loss:36.341
# [50,    4] loss:30.545
# [50,    6] loss:32.606
# [50,    8] loss:21.199
# Test set: Average loss: 0.5484
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split2.pkl')
train_test2(model.to(device),50,2)
# Out:
# [1,    2] loss:28.352
# [1,    4] loss:28.484
# [1,    6] loss:31.850
# [1,    8] loss:18.504
# Test set: Average loss: 0.5789
# [2,    2] loss:37.533
# [2,    4] loss:29.868
# [2,    6] loss:32.150
# [2,    8] loss:14.363
# Test set: Average loss: 0.6499
# [3,    2] loss:29.274
# [3,    4] loss:28.301
# [3,    6] loss:33.505
# [3,    8] loss:23.547
# Test set: Average loss: 0.5621
# [4,    2] loss:37.699
# [4,    4] loss:29.723
# [4,    6] loss:33.733
# [4,    8] loss:19.322
# Test set: Average loss: 0.6078
# [5,    2] loss:27.001
# [5,    4] loss:28.757
# [5,    6] loss:31.292
# [5,    8] loss:26.414
# Test set: Average loss: 0.6390
# [6,    2] loss:32.033
# [6,    4] loss:32.660
# [6,    6] loss:29.449
# [6,    8] loss:22.307
# Test set: Average loss: 0.6188
# [7,    2] loss:34.933
# [7,    4] loss:26.355
# [7,    6] loss:31.556
# [7,    8] loss:18.740
# Test set: Average loss: 0.6951
# [8,    2] loss:26.126
# [8,    4] loss:29.786
# [8,    6] loss:24.717
# [8,    8] loss:20.434
# Test set: Average loss: 0.6522
# [9,    2] loss:27.631
# [9,    4] loss:28.285
# [9,    6] loss:30.080
# [9,    8] loss:18.503
# Test set: Average loss: 0.6297
# [10,    2] loss:35.921
# [10,    4] loss:38.977
# [10,    6] loss:27.711
# [10,    8] loss:12.058
# Test set: Average loss: 0.6642
# [11,    2] loss:28.231
# [11,    4] loss:33.480
# [11,    6] loss:29.259
# [11,    8] loss:16.811
# Test set: Average loss: 0.5831
# [12,    2] loss:28.557
# [12,    4] loss:31.712
# [12,    6] loss:25.820
# [12,    8] loss:16.745
# Test set: Average loss: 0.6121
# [13,    2] loss:22.261
# [13,    4] loss:30.862
# [13,    6] loss:28.337
# [13,    8] loss:16.646
# Test set: Average loss: 0.6542
# [14,    2] loss:32.174
# [14,    4] loss:22.520
# [14,    6] loss:24.472
# [14,    8] loss:16.598
# Test set: Average loss: 0.7229
# [15,    2] loss:34.350
# [15,    4] loss:26.678
# [15,    6] loss:29.059
# [15,    8] loss:16.352
# Test set: Average loss: 0.6131
# [16,    2] loss:28.120
# [16,    4] loss:29.258
# [16,    6] loss:29.254
# [16,    8] loss:17.545
# Test set: Average loss: 0.7375
# [17,    2] loss:24.770
# [17,    4] loss:28.562
# [17,    6] loss:20.732
# [17,    8] loss:13.834
# Test set: Average loss: 0.6679
# [18,    2] loss:24.174
# [18,    4] loss:26.457
# [18,    6] loss:21.987
# [18,    8] loss:16.250
# Test set: Average loss: 0.6970
# [19,    2] loss:34.672
# [19,    4] loss:24.025
# [19,    6] loss:25.632
# [19,    8] loss:20.944
# Test set: Average loss: 0.6638
# [20,    2] loss:32.554
# [20,    4] loss:29.264
# [20,    6] loss:24.471
# [20,    8] loss:17.595
# Test set: Average loss: 0.6289
# [21,    2] loss:21.049
# [21,    4] loss:29.144
# [21,    6] loss:25.781
# [21,    8] loss:19.815
# Test set: Average loss: 0.6313
# [22,    2] loss:21.270
# [22,    4] loss:27.679
# [22,    6] loss:26.553
# [22,    8] loss:15.286
# Test set: Average loss: 0.6316
# [23,    2] loss:30.384
# [23,    4] loss:24.622
# [23,    6] loss:30.224
# [23,    8] loss:17.617
# Test set: Average loss: 0.7556
# [24,    2] loss:24.816
# [24,    4] loss:23.529
# [24,    6] loss:25.148
# [24,    8] loss:21.080
# Test set: Average loss: 0.6527
# [25,    2] loss:22.849
# [25,    4] loss:24.680
# [25,    6] loss:21.066
# [25,    8] loss:19.926
# Test set: Average loss: 0.6278
# [26,    2] loss:24.592
# [26,    4] loss:25.875
# [26,    6] loss:28.264
# [26,    8] loss:19.374
# Test set: Average loss: 0.6582
# [27,    2] loss:24.083
# [27,    4] loss:23.174
# [27,    6] loss:26.515
# [27,    8] loss:15.724
# Test set: Average loss: 0.6717
# [28,    2] loss:26.986
# [28,    4] loss:28.490
# [28,    6] loss:26.860
# [28,    8] loss:16.831
# Test set: Average loss: 0.6489
# [29,    2] loss:28.850
# [29,    4] loss:26.014
# [29,    6] loss:24.970
# [29,    8] loss:18.083
# Test set: Average loss: 0.7592
# [30,    2] loss:24.066
# [30,    4] loss:23.229
# [30,    6] loss:27.893
# [30,    8] loss:21.322
# Test set: Average loss: 0.6641
# [31,    2] loss:19.695
# [31,    4] loss:30.814
# [31,    6] loss:24.453
# [31,    8] loss:17.949
# Test set: Average loss: 0.6967
# [32,    2] loss:19.827
# [32,    4] loss:24.466
# [32,    6] loss:21.848
# [32,    8] loss:15.805
# Test set: Average loss: 0.7171
# [33,    2] loss:22.670
# [33,    4] loss:21.080
# [33,    6] loss:23.585
# [33,    8] loss:16.159
# Test set: Average loss: 0.7155
# [34,    2] loss:24.965
# [34,    4] loss:25.988
# [34,    6] loss:19.982
# [34,    8] loss:17.207
# Test set: Average loss: 0.6795
# [35,    2] loss:25.579
# [35,    4] loss:23.982
# [35,    6] loss:24.302
# [35,    8] loss:14.056
# Test set: Average loss: 0.7083
# [36,    2] loss:20.595
# [36,    4] loss:30.434
# [36,    6] loss:24.413
# [36,    8] loss:16.229
# Test set: Average loss: 0.6214
# [37,    2] loss:23.837
# [37,    4] loss:26.252
# [37,    6] loss:24.553
# [37,    8] loss:17.038
# Test set: Average loss: 0.8034
# [38,    2] loss:21.065
# [38,    4] loss:25.172
# [38,    6] loss:28.773
# [38,    8] loss:16.379
# Test set: Average loss: 0.7366
# [39,    2] loss:23.500
# [39,    4] loss:24.516
# [39,    6] loss:19.755
# [39,    8] loss:18.237
# Test set: Average loss: 0.6988
# [40,    2] loss:18.807
# [40,    4] loss:20.427
# [40,    6] loss:21.576
# [40,    8] loss:14.488
# Test set: Average loss: 0.6514
# [41,    2] loss:24.519
# [41,    4] loss:27.842
# [41,    6] loss:27.390
# [41,    8] loss:12.298
# Test set: Average loss: 0.7243
# [42,    2] loss:20.914
# [42,    4] loss:22.314
# [42,    6] loss:21.090
# [42,    8] loss:13.311
# Test set: Average loss: 0.5761
# [43,    2] loss:24.777
# [43,    4] loss:24.640
# [43,    6] loss:21.991
# [43,    8] loss:15.363
# Test set: Average loss: 0.5853
# [44,    2] loss:19.208
# [44,    4] loss:25.511
# [44,    6] loss:18.925
# [44,    8] loss:13.380
# Test set: Average loss: 0.6792
# [45,    2] loss:21.342
# [45,    4] loss:22.804
# [45,    6] loss:16.068
# [45,    8] loss:16.938
# Test set: Average loss: 0.5844
# [46,    2] loss:24.179
# [46,    4] loss:22.151
# [46,    6] loss:19.874
# [46,    8] loss:16.724
# Test set: Average loss: 0.7389
# [47,    2] loss:18.616
# [47,    4] loss:27.124
# [47,    6] loss:17.395
# [47,    8] loss:12.124
# Test set: Average loss: 0.6610
# [48,    2] loss:19.521
# [48,    4] loss:28.481
# [48,    6] loss:23.394
# [48,    8] loss:12.836
# Test set: Average loss: 0.7000
# [49,    2] loss:27.177
# [49,    4] loss:20.238
# [49,    6] loss:17.544
# [49,    8] loss:16.254
# Test set: Average loss: 0.6771
# [50,    2] loss:20.234
# [50,    4] loss:20.023
# [50,    6] loss:27.963
# [50,    8] loss:16.602
# Test set: Average loss: 0.6201
# Finished Training

# %%
#训练150个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split2.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：74%
# 测试集中不标准动作图片的预测精度为：56%
# 测试集中标准动作图片的预测精度为：89%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     30   23
# 1.0      7   59
