# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架提取后的图片数据集载入，划分训练集测试集'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited55/train/downdog'
test_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited55/test/downdog'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset = data1+data2+data3+data4+data5+data6+data7+data8
testset = torchvision.datasets.ImageFolder(root=test_path,transform=transform1) 
print(data1.class_to_idx)
BATCH_SIZE = 4
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# {'nonstandard': 0, 'standard': 1}

# %%
'''VGG19网络'''
import torchvision.models as models
import torch.nn as nn
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier[6] = nn.Linear(in_features=4096, out_features=2, bias=True)
'''for i in range(1,4):
  vgg19.classifier[i] = nn.Sequential()'''
print(vgg19)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/trainloss1_split.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/downdog/testloss1_split.csv',index=False)

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(vgg19.to(device))
# Out:
# 测试集精度为：46%
# 测试集中不标准动作图片的预测精度为：64%
# 测试集中标准动作图片的预测精度为：31%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     34   19
# 1.0     45   21

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(vgg19.to(device),50,50)
# Out:
# [1,   50] loss:3.013
# [1,  100] loss:3.184
# [1,  150] loss:3.283
# [1,  200] loss:3.310
# Test set: Average loss: 0.7323
# [2,   50] loss:3.125
# [2,  100] loss:3.069
# [2,  150] loss:3.054
# [2,  200] loss:3.201
# Test set: Average loss: 0.7562
# [3,   50] loss:2.856
# [3,  100] loss:2.984
# [3,  150] loss:2.913
# [3,  200] loss:2.796
# Test set: Average loss: 0.7032
# [4,   50] loss:2.791
# [4,  100] loss:2.597
# [4,  150] loss:2.839
# [4,  200] loss:3.004
# Test set: Average loss: 0.6333
# [5,   50] loss:2.831
# [5,  100] loss:2.822
# [5,  150] loss:2.958
# [5,  200] loss:2.764
# Test set: Average loss: 0.7139
# [6,   50] loss:2.707
# [6,  100] loss:2.635
# [6,  150] loss:2.722
# [6,  200] loss:2.742
# Test set: Average loss: 0.6933
# [7,   50] loss:2.653
# [7,  100] loss:2.620
# [7,  150] loss:2.568
# [7,  200] loss:2.759
# Test set: Average loss: 0.6740
# [8,   50] loss:2.549
# [8,  100] loss:2.501
# [8,  150] loss:2.658
# [8,  200] loss:2.540
# Test set: Average loss: 0.6822
# [9,   50] loss:2.574
# [9,  100] loss:2.586
# [9,  150] loss:2.724
# [9,  200] loss:2.469
# Test set: Average loss: 0.7130
# [10,   50] loss:2.506
# [10,  100] loss:2.468
# [10,  150] loss:2.569
# [10,  200] loss:2.629
# Test set: Average loss: 0.6941
# [11,   50] loss:2.794
# [11,  100] loss:2.604
# [11,  150] loss:2.366
# [11,  200] loss:2.489
# Test set: Average loss: 0.6189
# [12,   50] loss:2.636
# [12,  100] loss:2.467
# [44,  200] loss:1.089
# Test set: Average loss: 0.6965
# [45,   50] loss:0.946
# [45,  100] loss:0.998
# [45,  150] loss:1.011
# [45,  200] loss:0.952
# Test set: Average loss: 0.6802
# [46,   50] loss:1.146
# [46,  100] loss:0.791
# [46,  150] loss:0.843
# [46,  200] loss:1.009
# Test set: Average loss: 0.6762
# [47,   50] loss:0.764
# [47,  100] loss:1.210
# [47,  150] loss:1.116
# [47,  200] loss:0.875
# Test set: Average loss: 0.6689
# [48,   50] loss:0.882
# [48,  100] loss:0.738
# [48,  150] loss:1.074
# [48,  200] loss:1.053
# Test set: Average loss: 0.7114
# [49,   50] loss:0.998
# [49,  100] loss:1.126
# [49,  150] loss:1.067
# [49,  200] loss:1.074
# Test set: Average loss: 0.6723
# [50,   50] loss:1.215
# [50,  100] loss:0.965
# [50,  150] loss:0.852
# [50,  200] loss:1.053
# Test set: Average loss: 0.7803
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
train_test2(model.to(device),50,50)
# Out:
# [1,   50] loss:1.042
# [1,  100] loss:0.857
# [1,  150] loss:1.099
# [1,  200] loss:0.796
# Test set: Average loss: 0.8194
# [2,   50] loss:0.995
# [2,  100] loss:0.975
# [2,  150] loss:0.987
# [2,  200] loss:0.876
# Test set: Average loss: 0.6503
# [3,   50] loss:0.941
# [3,  100] loss:1.074
# [3,  150] loss:0.810
# [3,  200] loss:0.923
# Test set: Average loss: 0.7604
# [4,   50] loss:1.181
# [4,  100] loss:0.960
# [4,  150] loss:0.831
# [4,  200] loss:0.900
# Test set: Average loss: 0.7278
# [5,   50] loss:0.865
# [5,  100] loss:0.935
# [5,  150] loss:1.052
# [5,  200] loss:0.924
# Test set: Average loss: 0.6818
# [6,   50] loss:0.885
# [6,  100] loss:0.933
# [6,  150] loss:0.911
# [6,  200] loss:0.749
# Test set: Average loss: 0.7320
# [7,   50] loss:0.899
# [7,  100] loss:1.041
# [7,  150] loss:0.991
# [7,  200] loss:0.680
# Test set: Average loss: 0.7198
# [8,   50] loss:1.023
# [8,  100] loss:0.823
# [8,  150] loss:0.993
# [8,  200] loss:0.704
# Test set: Average loss: 0.7225
# [9,   50] loss:0.779
# [9,  100] loss:0.758
# [9,  150] loss:0.755
# [9,  200] loss:0.837
# Test set: Average loss: 0.6741
# [10,   50] loss:0.811
# [10,  100] loss:0.930
# [10,  150] loss:0.812
# [10,  200] loss:1.057
# Test set: Average loss: 0.7811
# [11,   50] loss:0.998
# [11,  100] loss:0.745
# [11,  150] loss:1.030
# [11,  200] loss:0.697
# Test set: Average loss: 0.7793
# [12,   50] loss:1.089
# [12,  100] loss:0.751
# [12,  150] loss:0.953
# [12,  200] loss:0.966
# Test set: Average loss: 0.7362
# [13,   50] loss:0.833
# [13,  100] loss:0.844
# [13,  150] loss:1.131
# [13,  200] loss:0.755
# Test set: Average loss: 0.6821
# [14,   50] loss:0.994
# [14,  100] loss:0.764
# [14,  150] loss:0.766
# [14,  200] loss:0.987
# Test set: Average loss: 0.7353
# [15,   50] loss:0.714
# [15,  100] loss:0.827
# [15,  150] loss:0.903
# [15,  200] loss:0.960
# Test set: Average loss: 0.7586
# [16,   50] loss:0.871
# [16,  100] loss:1.017
# [16,  150] loss:0.835
# [16,  200] loss:0.749
# Test set: Average loss: 0.7391
# [17,   50] loss:0.939
# [17,  100] loss:0.932
# [17,  150] loss:0.932
# [17,  200] loss:0.725
# Test set: Average loss: 0.7683
# [18,   50] loss:0.918
# [18,  100] loss:0.992
# [18,  150] loss:0.906
# [18,  200] loss:0.682
# Test set: Average loss: 0.8396
# [19,   50] loss:0.778
# [19,  100] loss:0.782
# [19,  150] loss:0.842
# [19,  200] loss:0.820
# Test set: Average loss: 0.7253
# [20,   50] loss:0.866
# [20,  100] loss:0.746
# [20,  150] loss:0.830
# [20,  200] loss:0.924
# Test set: Average loss: 0.6269
# [21,   50] loss:0.721
# [21,  100] loss:0.818
# [21,  150] loss:0.730
# [21,  200] loss:0.830
# Test set: Average loss: 0.7393
# [22,   50] loss:0.696
# [22,  100] loss:0.673
# [22,  150] loss:0.637
# [22,  200] loss:0.744
# Test set: Average loss: 0.7371
# [23,   50] loss:0.790
# [23,  100] loss:0.853
# [23,  150] loss:0.800
# [23,  200] loss:0.661
# Test set: Average loss: 0.8041
# [24,   50] loss:0.816
# [24,  100] loss:0.607
# [24,  150] loss:0.672
# [24,  200] loss:0.893
# Test set: Average loss: 0.6597
# [25,   50] loss:0.610
# [25,  100] loss:0.790
# [25,  150] loss:0.813
# [25,  200] loss:0.833
# Test set: Average loss: 0.7505
# [26,   50] loss:0.613
# [26,  100] loss:0.800
# [26,  150] loss:0.784
# [26,  200] loss:0.585
# Test set: Average loss: 0.7067
# [27,   50] loss:0.870
# [27,  100] loss:0.873
# [27,  150] loss:0.880
# [27,  200] loss:0.801
# Test set: Average loss: 0.7742
# [28,   50] loss:0.740
# [28,  100] loss:1.013
# [28,  150] loss:0.689
# [28,  200] loss:0.706
# Test set: Average loss: 0.7497
# [29,   50] loss:0.750
# [29,  100] loss:0.672
# [29,  150] loss:0.720
# [29,  200] loss:0.864
# Test set: Average loss: 0.7435
# [30,   50] loss:0.579
# [30,  100] loss:0.771
# [30,  150] loss:0.767
# [30,  200] loss:0.578
# Test set: Average loss: 0.7066
# [31,   50] loss:0.683
# [31,  100] loss:0.795
# [31,  150] loss:0.746
# [31,  200] loss:0.795
# Test set: Average loss: 0.8112
# [32,   50] loss:0.912
# [32,  100] loss:0.592
# [32,  150] loss:0.783
# [32,  200] loss:0.839
# Test set: Average loss: 0.7255
# [33,   50] loss:0.977
# [33,  100] loss:0.643
# [33,  150] loss:0.698
# [33,  200] loss:0.733
# Test set: Average loss: 0.8643
# [34,   50] loss:0.660
# [34,  100] loss:0.829
# [34,  150] loss:0.780
# [34,  200] loss:0.648
# Test set: Average loss: 0.7683
# [35,   50] loss:1.022
# [35,  100] loss:0.642
# [35,  150] loss:0.600
# [35,  200] loss:0.712
# Test set: Average loss: 0.7271
# [36,   50] loss:0.793
# [36,  100] loss:0.684
# [36,  150] loss:0.701
# [36,  200] loss:0.733
# Test set: Average loss: 0.6564
# [37,   50] loss:0.619
# [37,  100] loss:0.871
# [37,  150] loss:0.829
# [37,  200] loss:0.773
# Test set: Average loss: 0.7199
# [38,   50] loss:0.559
# [38,  100] loss:0.793
# [38,  150] loss:0.710
# [38,  200] loss:0.763
# Test set: Average loss: 0.8572
# [39,   50] loss:0.735
# [39,  100] loss:0.569
# [39,  150] loss:0.657
# [39,  200] loss:0.681
# Test set: Average loss: 0.7668
# [40,   50] loss:0.653
# [40,  100] loss:0.621
# [40,  150] loss:0.833
# [40,  200] loss:0.772
# Test set: Average loss: 0.7892
# [41,   50] loss:0.785
# [41,  100] loss:0.876
# [41,  150] loss:0.550
# [41,  200] loss:0.721
# Test set: Average loss: 0.9311
# [42,   50] loss:0.888
# [42,  100] loss:0.479
# [42,  150] loss:0.644
# [42,  200] loss:0.722
# Test set: Average loss: 0.7922
# [43,   50] loss:0.687
# [43,  100] loss:0.538
# [43,  150] loss:0.564
# [43,  200] loss:0.606
# Test set: Average loss: 0.7918
# [44,   50] loss:0.813
# [44,  100] loss:0.693
# [44,  150] loss:0.592
# [44,  200] loss:0.723
# Test set: Average loss: 0.7724
# [45,   50] loss:0.832
# [45,  100] loss:0.952
# [45,  150] loss:0.602
# [45,  200] loss:0.560
# Test set: Average loss: 0.7728
# [46,   50] loss:0.510
# [46,  100] loss:0.820
# [46,  150] loss:0.990
# [46,  200] loss:0.685
# Test set: Average loss: 0.8770
# [47,   50] loss:0.655
# [47,  100] loss:0.741
# [47,  150] loss:0.790
# [47,  200] loss:0.685
# Test set: Average loss: 0.8288
# [48,   50] loss:0.776
# [48,  100] loss:0.698
# [48,  150] loss:0.656
# [48,  200] loss:0.518
# Test set: Average loss: 0.8154
# [49,   50] loss:0.758
# [49,  100] loss:0.770
# [49,  150] loss:0.574
# [49,  200] loss:0.728
# Test set: Average loss: 0.7964
# [50,   50] loss:0.570
# [50,  100] loss:0.518
# [50,  150] loss:0.726
# [50,  200] loss:0.685
# Test set: Average loss: 0.7854
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
train_test2(model.to(device),50,50)
# Out:
# [1,   50] loss:0.773
# [1,  100] loss:0.700
# [1,  150] loss:0.496
# [1,  200] loss:0.892
# Test set: Average loss: 0.7519
# [2,   50] loss:0.476
# [2,  100] loss:0.829
# [2,  150] loss:0.558
# [2,  200] loss:0.655
# Test set: Average loss: 0.8109
# [3,   50] loss:0.870
# [3,  100] loss:0.617
# [3,  150] loss:0.697
# [3,  200] loss:0.474
# Test set: Average loss: 0.8253
# [4,   50] loss:0.801
# [4,  100] loss:0.529
# [4,  150] loss:0.674
# [4,  200] loss:0.777
# Test set: Average loss: 0.8041
# [5,   50] loss:0.685
# [5,  100] loss:0.491
# [5,  150] loss:0.478
# [5,  200] loss:0.820
# Test set: Average loss: 0.8186
# [6,   50] loss:0.798
# [6,  100] loss:0.608
# [6,  150] loss:0.617
# [6,  200] loss:0.682
# Test set: Average loss: 0.8605
# [7,   50] loss:0.609
# [7,  100] loss:0.426
# [7,  150] loss:0.574
# [7,  200] loss:0.543
# Test set: Average loss: 0.7557
# [8,   50] loss:0.821
# [8,  100] loss:0.606
# [8,  150] loss:0.572
# [8,  200] loss:0.655
# Test set: Average loss: 0.9703
# [9,   50] loss:0.779
# [9,  100] loss:0.840
# [9,  150] loss:0.647
# [9,  200] loss:0.580
# Test set: Average loss: 0.9126
# [10,   50] loss:0.648
# [10,  100] loss:0.646
# [10,  150] loss:0.662
# [10,  200] loss:0.576
# Test set: Average loss: 0.7298
# [11,   50] loss:0.674
# [11,  100] loss:0.625
# [11,  150] loss:0.682
# [11,  200] loss:0.341
# Test set: Average loss: 0.8520
# [12,   50] loss:0.598
# [12,  100] loss:0.586
# [12,  150] loss:0.567
# [12,  200] loss:0.472
# Test set: Average loss: 0.8681
# [13,   50] loss:0.708
# [13,  100] loss:0.483
# [13,  150] loss:0.618
# [13,  200] loss:0.782
# Test set: Average loss: 0.8987
# [14,   50] loss:0.732
# [14,  100] loss:0.866
# [14,  150] loss:0.425
# [14,  200] loss:0.790
# Test set: Average loss: 0.8366
# [15,   50] loss:0.613
# [15,  100] loss:0.836
# [15,  150] loss:0.626
# [15,  200] loss:0.644
# Test set: Average loss: 0.7932
# [16,   50] loss:0.522
# [16,  100] loss:0.936
# [16,  150] loss:0.597
# [16,  200] loss:0.479
# Test set: Average loss: 0.6978
# [17,   50] loss:0.494
# [17,  100] loss:0.465
# [17,  150] loss:0.637
# [17,  200] loss:0.717
# Test set: Average loss: 0.8408
# [18,   50] loss:0.492
# [18,  100] loss:0.582
# [18,  150] loss:0.745
# [18,  200] loss:0.597
# Test set: Average loss: 0.8493
# [19,   50] loss:0.634
# [19,  100] loss:0.701
# [19,  150] loss:0.615
# [19,  200] loss:0.580
# Test set: Average loss: 0.9327
# [20,   50] loss:0.691
# [20,  100] loss:0.411
# [20,  150] loss:0.714
# [20,  200] loss:0.535
# Test set: Average loss: 0.7828
# [21,   50] loss:0.623
# [21,  100] loss:0.776
# [21,  150] loss:1.000
# [21,  200] loss:0.508
# Test set: Average loss: 0.7629
# [22,   50] loss:0.471
# [22,  100] loss:0.759
# [22,  150] loss:0.573
# [22,  200] loss:0.743
# Test set: Average loss: 0.7877
# [23,   50] loss:0.585
# [23,  100] loss:0.523
# [23,  150] loss:0.487
# [23,  200] loss:0.729
# Test set: Average loss: 0.8027
# [24,   50] loss:0.495
# [24,  100] loss:0.588
# [24,  150] loss:0.574
# [24,  200] loss:0.682
# Test set: Average loss: 0.9529
# [25,   50] loss:0.486
# [25,  100] loss:0.522
# [25,  150] loss:0.549
# [25,  200] loss:0.557
# Test set: Average loss: 0.9087
# [26,   50] loss:0.686
# [26,  100] loss:0.528
# [26,  150] loss:0.469
# [26,  200] loss:0.627
# Test set: Average loss: 0.8303
# [27,   50] loss:0.652
# [27,  100] loss:0.723
# [27,  150] loss:0.427
# [27,  200] loss:0.557
# Test set: Average loss: 0.8139
# [28,   50] loss:0.448
# [28,  100] loss:0.643
# [28,  150] loss:0.731
# [28,  200] loss:0.479
# Test set: Average loss: 0.8847
# [29,   50] loss:0.592
# [29,  100] loss:0.518
# [29,  150] loss:0.356
# [29,  200] loss:0.586
# Test set: Average loss: 0.7959
# [30,   50] loss:0.602
# [30,  100] loss:0.531
# [30,  150] loss:0.585
# [30,  200] loss:0.637
# Test set: Average loss: 0.7309
# [31,   50] loss:0.498
# [31,  100] loss:0.620
# [31,  150] loss:0.496
# [31,  200] loss:0.662
# Test set: Average loss: 0.8331
# [32,   50] loss:0.595
# [32,  100] loss:0.436
# [32,  150] loss:0.383
# [32,  200] loss:0.628
# Test set: Average loss: 0.7410
# [33,   50] loss:0.859
# [33,  100] loss:0.546
# [33,  150] loss:0.495
# [33,  200] loss:0.561
# Test set: Average loss: 0.7957
# [34,   50] loss:0.812
# [34,  100] loss:0.512
# [34,  150] loss:0.472
# [34,  200] loss:0.488
# Test set: Average loss: 0.8471
# [35,   50] loss:0.383
# [35,  100] loss:0.620
# [35,  150] loss:0.613
# [35,  200] loss:0.472
# Test set: Average loss: 0.8531
# [36,   50] loss:0.628
# [36,  100] loss:0.495
# [36,  150] loss:0.311
# [36,  200] loss:0.735
# Test set: Average loss: 0.8200
# [37,   50] loss:0.724
# [37,  100] loss:0.600
# [37,  150] loss:0.612
# [37,  200] loss:0.550
# Test set: Average loss: 0.8854
# [38,   50] loss:0.560
# [38,  100] loss:0.513
# [38,  150] loss:0.610
# [38,  200] loss:0.516
# Test set: Average loss: 0.8358
# [39,   50] loss:0.617
# [39,  100] loss:0.580
# [39,  150] loss:0.576
# [39,  200] loss:0.634
# Test set: Average loss: 0.8518
# [40,   50] loss:0.544
# [40,  100] loss:0.649
# [40,  150] loss:0.664
# [40,  200] loss:0.480
# Test set: Average loss: 0.8431
# [41,   50] loss:0.715
# [41,  100] loss:0.629
# [41,  150] loss:0.591
# [41,  200] loss:0.359
# Test set: Average loss: 0.8311
# [42,   50] loss:0.478
# [42,  100] loss:0.488
# [42,  150] loss:0.593
# [42,  200] loss:0.753
# Test set: Average loss: 0.8934
# [43,   50] loss:0.701
# [43,  100] loss:0.475
# [43,  150] loss:0.652
# [43,  200] loss:0.582
# Test set: Average loss: 0.7889
# [44,   50] loss:0.641
# [44,  100] loss:0.438
# [44,  150] loss:0.661
# [44,  200] loss:0.540
# Test set: Average loss: 0.8823
# [45,   50] loss:0.583
# [45,  100] loss:0.670
# [45,  150] loss:0.586
# [45,  200] loss:0.507
# Test set: Average loss: 0.8951
# [46,   50] loss:0.634
# [46,  100] loss:0.625
# [46,  150] loss:0.310
# [46,  200] loss:0.611
# Test set: Average loss: 0.8490
# [47,   50] loss:0.565
# [47,  100] loss:0.479
# [47,  150] loss:0.439
# [47,  200] loss:0.509
# Test set: Average loss: 0.8057
# [48,   50] loss:0.491
# [48,  100] loss:0.524
# [48,  150] loss:0.477
# [48,  200] loss:0.579
# Test set: Average loss: 0.8759
# [49,   50] loss:0.647
# [49,  100] loss:0.469
# [49,  150] loss:0.612
# [49,  200] loss:0.567
# Test set: Average loss: 0.8285
# [50,   50] loss:0.623
# [50,  100] loss:0.548
# [50,  150] loss:0.520
# [50,  200] loss:0.462
# Test set: Average loss: 0.8371
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
train_test2(model.to(device),50,50)
# Out:
# [1,   50] loss:0.580
# [1,  100] loss:0.599
# [1,  150] loss:0.503
# [1,  200] loss:0.690
# Test set: Average loss: 0.9327
# [2,   50] loss:0.626
# [2,  100] loss:0.345
# [2,  150] loss:0.574
# [2,  200] loss:0.348
# Test set: Average loss: 0.8377
# [3,   50] loss:0.407
# [3,  100] loss:0.445
# [3,  150] loss:0.649
# [3,  200] loss:0.517
# Test set: Average loss: 0.8632
# [4,   50] loss:0.441
# [4,  100] loss:0.477
# [4,  150] loss:0.463
# [4,  200] loss:0.591
# Test set: Average loss: 0.8430
# [5,   50] loss:0.607
# [5,  100] loss:0.508
# [5,  150] loss:0.590
# [5,  200] loss:0.440
# Test set: Average loss: 0.8862
# [6,   50] loss:0.369
# [6,  100] loss:0.388
# [6,  150] loss:0.660
# [6,  200] loss:0.572
# Test set: Average loss: 0.9574
# [7,   50] loss:0.567
# [7,  100] loss:0.686
# [7,  150] loss:0.794
# [7,  200] loss:0.400
# Test set: Average loss: 0.9149
# [8,   50] loss:0.388
# [8,  100] loss:0.518
# [8,  150] loss:0.654
# [8,  200] loss:0.728
# Test set: Average loss: 0.8198
# [9,   50] loss:0.356
# [9,  100] loss:0.664
# [9,  150] loss:0.612
# [9,  200] loss:0.586
# Test set: Average loss: 0.8322
# [10,   50] loss:0.403
# [10,  100] loss:0.701
# [10,  150] loss:0.557
# [10,  200] loss:0.463
# Test set: Average loss: 0.8962
# [11,   50] loss:0.503
# [11,  100] loss:0.515
# [11,  150] loss:0.688
# [11,  200] loss:0.439
# Test set: Average loss: 0.9100
# [12,   50] loss:0.626
# [12,  100] loss:0.358
# [12,  150] loss:0.572
# [12,  200] loss:0.708
# Test set: Average loss: 0.8684
# [13,   50] loss:0.287
# [13,  100] loss:0.485
# [13,  150] loss:0.598
# [13,  200] loss:0.585
# Test set: Average loss: 0.7783
# [14,   50] loss:0.643
# [14,  100] loss:0.371
# [14,  150] loss:0.557
# [14,  200] loss:0.446
# Test set: Average loss: 0.7949
# [15,   50] loss:0.301
# [15,  100] loss:0.575
# [15,  150] loss:0.395
# [15,  200] loss:0.540
# Test set: Average loss: 0.7733
# [16,   50] loss:0.520
# [16,  100] loss:0.637
# [16,  150] loss:0.473
# [16,  200] loss:0.495
# Test set: Average loss: 0.8469
# [17,   50] loss:0.506
# [17,  100] loss:0.419
# [17,  150] loss:0.590
# [17,  200] loss:0.384
# Test set: Average loss: 0.9604
# [18,   50] loss:0.442
# [18,  100] loss:0.489
# [18,  150] loss:0.468
# [18,  200] loss:0.579
# Test set: Average loss: 0.9238
# [19,   50] loss:0.539
# [19,  100] loss:0.663
# [19,  150] loss:0.416
# [19,  200] loss:0.495
# Test set: Average loss: 0.9739
# [20,   50] loss:0.593
# [20,  100] loss:0.562
# [20,  150] loss:0.542
# [20,  200] loss:0.534
# Test set: Average loss: 0.7916
# [21,   50] loss:0.309
# [21,  100] loss:0.597
# [21,  150] loss:0.439
# [21,  200] loss:0.540
# Test set: Average loss: 0.9668
# [22,   50] loss:0.538
# [22,  100] loss:0.495
# [22,  150] loss:0.402
# [22,  200] loss:0.512
# Test set: Average loss: 0.8636
# [23,   50] loss:0.445
# [23,  100] loss:0.339
# [23,  150] loss:0.403
# [23,  200] loss:0.357
# Test set: Average loss: 0.8932
# [24,   50] loss:0.438
# [24,  100] loss:0.412
# [24,  150] loss:0.520
# [24,  200] loss:0.413
# Test set: Average loss: 0.9306
# [25,   50] loss:0.626
# [25,  100] loss:0.335
# [25,  150] loss:0.573
# [25,  200] loss:0.400
# Test set: Average loss: 0.9840
# [26,   50] loss:0.531
# [26,  100] loss:0.475
# [26,  150] loss:0.398
# [26,  200] loss:0.348
# Test set: Average loss: 0.9591
# [27,   50] loss:0.414
# [27,  100] loss:0.548
# [27,  150] loss:0.538
# [27,  200] loss:0.464
# Test set: Average loss: 0.9273
# [28,   50] loss:0.453
# [28,  100] loss:0.363
# [28,  150] loss:0.536
# [28,  200] loss:0.543
# Test set: Average loss: 0.9000
# [29,   50] loss:0.399
# [29,  100] loss:0.771
# [29,  150] loss:0.360
# [29,  200] loss:0.299
# Test set: Average loss: 0.9208
# [30,   50] loss:0.462
# [30,  100] loss:0.547
# [30,  150] loss:0.543
# [30,  200] loss:0.485
# Test set: Average loss: 0.8940
# [31,   50] loss:0.483
# [31,  100] loss:0.652
# [31,  150] loss:0.473
# [31,  200] loss:0.300
# Test set: Average loss: 0.9075
# [32,   50] loss:0.414
# [32,  100] loss:0.622
# [32,  150] loss:0.401
# [32,  200] loss:0.652
# Test set: Average loss: 0.9302
# [33,   50] loss:0.739
# [33,  100] loss:0.437
# [33,  150] loss:0.392
# [33,  200] loss:0.312
# Test set: Average loss: 0.8389
# [34,   50] loss:0.388
# [34,  100] loss:0.509
# [34,  150] loss:0.761
# [34,  200] loss:0.442
# Test set: Average loss: 0.9202
# [35,   50] loss:0.241
# [35,  100] loss:0.588
# [35,  150] loss:0.318
# [35,  200] loss:0.677
# Test set: Average loss: 0.9846
# [36,   50] loss:0.388
# [36,  100] loss:0.427
# [36,  150] loss:0.503
# [36,  200] loss:0.414
# Test set: Average loss: 0.9026
# [37,   50] loss:0.472
# [37,  100] loss:0.508
# [37,  150] loss:0.364
# [37,  200] loss:0.434
# Test set: Average loss: 0.9045
# [38,   50] loss:0.616
# [38,  100] loss:0.353
# [38,  150] loss:0.553
# [38,  200] loss:0.701
# Test set: Average loss: 0.8853
# [39,   50] loss:0.445
# [39,  100] loss:0.476
# [39,  150] loss:0.426
# [39,  200] loss:0.687
# Test set: Average loss: 1.0269
# [40,   50] loss:0.336
# [40,  100] loss:0.408
# [40,  150] loss:0.479
# [40,  200] loss:0.575
# Test set: Average loss: 0.9339
# [41,   50] loss:0.595
# [41,  100] loss:0.474
# [41,  150] loss:0.480
# [41,  200] loss:0.452
# Test set: Average loss: 0.9431
# [42,   50] loss:0.363
# [42,  100] loss:0.446
# [42,  150] loss:0.519
# [42,  200] loss:0.423
# Test set: Average loss: 0.9856
# [43,   50] loss:0.512
# [43,  100] loss:0.532
# [43,  150] loss:0.455
# [43,  200] loss:0.369
# Test set: Average loss: 0.9949
# [44,   50] loss:0.388
# [44,  100] loss:0.492
# [44,  150] loss:0.476
# [44,  200] loss:0.585
# Test set: Average loss: 0.9454
# [45,   50] loss:0.323
# [45,  100] loss:0.298
# [45,  150] loss:0.668
# [45,  200] loss:0.511
# Test set: Average loss: 0.9838
# [46,   50] loss:0.381
# [46,  100] loss:0.514
# [46,  150] loss:0.731
# [46,  200] loss:0.395
# Test set: Average loss: 0.9978
# [47,   50] loss:0.473
# [47,  100] loss:0.416
# [47,  150] loss:0.347
# [47,  200] loss:0.334
# Test set: Average loss: 0.8758
# [48,   50] loss:0.396
# [48,  100] loss:0.380
# [48,  150] loss:0.466
# [48,  200] loss:0.520
# Test set: Average loss: 0.8946
# [49,   50] loss:0.414
# [49,  100] loss:0.447
# [49,  150] loss:0.311
# [49,  200] loss:0.584
# Test set: Average loss: 0.8841
# [50,   50] loss:0.591
# [50,  100] loss:0.407
# [50,  150] loss:0.491
# [50,  200] loss:0.285
# Test set: Average loss: 0.9375
# Finished Training

# %%
#训练150个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：75%
# 测试集中不标准动作图片的预测精度为：64%
# 测试集中标准动作图片的预测精度为：84%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     34   19
# 1.0     10   56

# %%
#训练200个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：78%
# 测试集中不标准动作图片的预测精度为：69%
# 测试集中标准动作图片的预测精度为：86%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     37   16
# 1.0      9   57

# %%
#训练250个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/downdog/YogaEvaNet_downdog1_split.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：76%
# 测试集中不标准动作图片的预测精度为：66%
# 测试集中标准动作图片的预测精度为：84%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     35   18
# 1.0     10   56
