# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架提取后的图片数据集载入，划分训练集测试集'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/train/goddess'
test_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/test/goddess'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset = data1+data2+data3+data4+data5+data6+data7+data8
testset = torchvision.datasets.ImageFolder(root=test_path,transform=transform1) 
print(data1.class_to_idx)
BATCH_SIZE = 4
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# {'nonstandard': 0, 'standard': 1}

# %%
'''VGG19网络'''
import torchvision.models as models
import torch.nn as nn
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier[6] = nn.Linear(in_features=4096, out_features=2, bias=True)
'''for i in range(6):
  vgg19.classifier[i] = nn.Sequential()'''
print(vgg19)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast1.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast1.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast1.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast1.csv',index=False)

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(vgg19.to(device))
# Out:
# 测试集精度为：44%
# 测试集中不标准动作图片的预测精度为：48%
# 测试集中标准动作图片的预测精度为：39%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     15   16
# 1.0     17   11

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(vgg19.to(device),50,100)
# Out:
# [1,  100] loss:3.315
# [1,  200] loss:3.269
# Test set: Average loss: 0.7267
# [2,  100] loss:3.030
# [2,  200] loss:2.987
# Test set: Average loss: 0.7985
# [3,  100] loss:2.986
# [3,  200] loss:2.754
# Test set: Average loss: 0.6392
# [4,  100] loss:2.776
# [4,  200] loss:2.698
# Test set: Average loss: 0.6969
# [5,  100] loss:2.593
# [5,  200] loss:2.645
# Test set: Average loss: 0.6619
# [6,  100] loss:2.706
# [6,  200] loss:2.594
# Test set: Average loss: 0.7981
# [7,  100] loss:2.478
# [7,  200] loss:2.435
# Test set: Average loss: 0.6651
# [8,  100] loss:2.390
# [8,  200] loss:2.465
# Test set: Average loss: 0.6145
# [9,  100] loss:2.360
# [9,  200] loss:2.381
# Test set: Average loss: 0.6490
# [10,  100] loss:2.271
# [10,  200] loss:2.225
# Test set: Average loss: 0.6787
# [11,  100] loss:2.240
# [11,  200] loss:2.274
# Test set: Average loss: 0.6583
# [12,  100] loss:2.167
# [12,  200] loss:2.069
# Test set: Average loss: 0.7364
# [13,  100] loss:2.086
# [13,  200] loss:2.081
# Test set: Average loss: 0.6128
# [14,  100] loss:1.945
# [14,  200] loss:1.911
# Test set: Average loss: 0.5984
# [15,  100] loss:1.894
# [15,  200] loss:1.848
# Test set: Average loss: 0.5976
# [16,  100] loss:1.897
# [16,  200] loss:1.957
# Test set: Average loss: 0.5797
# [17,  100] loss:1.863
# [17,  200] loss:1.871
# Test set: Average loss: 0.5483
# [18,  100] loss:1.789
# [18,  200] loss:1.896
# Test set: Average loss: 0.7233
# [19,  100] loss:1.712
# [19,  200] loss:1.734
# Test set: Average loss: 0.6703
# [20,  100] loss:1.635
# [20,  200] loss:1.642
# Test set: Average loss: 0.5141
# [21,  100] loss:1.581
# [21,  200] loss:1.673
# Test set: Average loss: 0.5728
# [22,  100] loss:1.447
# [22,  200] loss:1.589
# Test set: Average loss: 0.5368
# [23,  100] loss:1.560
# [23,  200] loss:1.560
# Test set: Average loss: 0.7015
# [24,  100] loss:1.576
# [24,  200] loss:1.415
# Test set: Average loss: 0.6240
# [25,  100] loss:1.593
# [25,  200] loss:1.462
# Test set: Average loss: 0.7249
# [26,  100] loss:1.279
# [26,  200] loss:1.489
# Test set: Average loss: 0.6640
# [27,  100] loss:1.431
# [27,  200] loss:1.288
# Test set: Average loss: 0.7148
# [28,  100] loss:1.407
# [28,  200] loss:1.388
# Test set: Average loss: 0.5913
# [29,  100] loss:1.344
# [29,  200] loss:1.192
# Test set: Average loss: 0.6593
# [30,  100] loss:1.304
# [30,  200] loss:1.288
# Test set: Average loss: 0.5894
# [31,  100] loss:1.101
# [31,  200] loss:1.176
# Test set: Average loss: 0.6271
# [32,  100] loss:1.229
# [32,  200] loss:1.183
# Test set: Average loss: 0.6254
# [33,  100] loss:1.106
# [33,  200] loss:1.228
# Test set: Average loss: 0.6070
# [34,  100] loss:1.010
# [34,  200] loss:1.130
# Test set: Average loss: 0.6631
# [35,  100] loss:1.208
# [35,  200] loss:1.015
# Test set: Average loss: 0.7443
# [36,  100] loss:1.111
# [36,  200] loss:0.934
# Test set: Average loss: 0.8423
# [37,  100] loss:1.046
# [37,  200] loss:1.002
# Test set: Average loss: 0.7242
# [38,  100] loss:1.165
# [38,  200] loss:1.034
# Test set: Average loss: 0.7068
# [39,  100] loss:1.096
# [39,  200] loss:1.043
# Test set: Average loss: 0.8213
# [40,  100] loss:1.160
# [40,  200] loss:0.853
# Test set: Average loss: 0.7464
# [41,  100] loss:1.063
# [41,  200] loss:0.939
# Test set: Average loss: 0.8396
# [42,  100] loss:0.882
# [42,  200] loss:1.064
# Test set: Average loss: 0.8117
# [43,  100] loss:0.983
# [43,  200] loss:1.145
# Test set: Average loss: 0.7639
# [44,  100] loss:0.988
# [44,  200] loss:0.881
# Test set: Average loss: 0.7319
# [45,  100] loss:0.884
# [45,  200] loss:0.926
# Test set: Average loss: 0.8286
# [46,  100] loss:0.923
# [46,  200] loss:0.882
# Test set: Average loss: 0.8386
# [47,  100] loss:0.885
# [47,  200] loss:0.849
# Test set: Average loss: 0.7232
# [48,  100] loss:0.777
# [48,  200] loss:1.019
# Test set: Average loss: 0.8690
# [49,  100] loss:0.788
# [49,  200] loss:0.743
# Test set: Average loss: 0.8013
# [50,  100] loss:0.876
# [50,  200] loss:0.852
# Test set: Average loss: 0.7693
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.852
# [1,  200] loss:0.865
# Test set: Average loss: 0.8004
# [2,  100] loss:0.681
# [2,  200] loss:0.860
# Test set: Average loss: 0.8395
# [3,  100] loss:0.835
# [3,  200] loss:0.777
# Test set: Average loss: 0.8236
# [4,  100] loss:0.770
# [4,  200] loss:0.800
# Test set: Average loss: 0.8185
# [5,  100] loss:0.843
# [5,  200] loss:0.720
# Test set: Average loss: 0.8811
# [6,  100] loss:0.751
# [6,  200] loss:0.746
# Test set: Average loss: 0.9102
# [7,  100] loss:0.753
# [7,  200] loss:0.764
# Test set: Average loss: 0.8671
# [8,  100] loss:0.830
# [8,  200] loss:0.738
# Test set: Average loss: 0.9048
# [9,  100] loss:0.828
# [9,  200] loss:0.616
# Test set: Average loss: 0.9839
# [10,  100] loss:0.785
# [10,  200] loss:0.751
# Test set: Average loss: 1.0023
# [11,  100] loss:0.656
# [11,  200] loss:0.688
# Test set: Average loss: 0.8910
# [12,  100] loss:0.770
# [12,  200] loss:0.635
# Test set: Average loss: 0.8880
# [13,  100] loss:0.755
# [13,  200] loss:0.710
# Test set: Average loss: 0.9342
# [14,  100] loss:0.594
# [14,  200] loss:0.707
# Test set: Average loss: 0.8338
# [15,  100] loss:0.715
# [15,  200] loss:0.600
# Test set: Average loss: 0.8925
# [16,  100] loss:0.840
# [16,  200] loss:0.569
# Test set: Average loss: 0.8899
# [17,  100] loss:0.549
# [17,  200] loss:0.660
# Test set: Average loss: 0.9218
# [18,  100] loss:0.652
# [18,  200] loss:0.731
# Test set: Average loss: 0.9948
# [19,  100] loss:0.564
# [19,  200] loss:0.642
# Test set: Average loss: 0.8481
# [20,  100] loss:0.685
# [20,  200] loss:0.644
# Test set: Average loss: 0.9437
# [21,  100] loss:0.715
# [21,  200] loss:0.571
# Test set: Average loss: 1.1156
# [22,  100] loss:0.660
# [22,  200] loss:0.647
# Test set: Average loss: 0.9846
# [23,  100] loss:0.578
# [23,  200] loss:0.657
# Test set: Average loss: 0.8525
# [24,  100] loss:0.636
# [24,  200] loss:0.526
# Test set: Average loss: 0.9621
# [25,  100] loss:0.621
# [25,  200] loss:0.607
# Test set: Average loss: 1.1341
# [26,  100] loss:0.670
# [26,  200] loss:0.607
# Test set: Average loss: 0.8889
# [27,  100] loss:0.718
# [27,  200] loss:0.545
# Test set: Average loss: 0.8373
# [28,  100] loss:0.571
# [28,  200] loss:0.664
# Test set: Average loss: 0.9994
# [29,  100] loss:0.509
# [29,  200] loss:0.500
# Test set: Average loss: 1.0749
# [30,  100] loss:0.641
# [30,  200] loss:0.586
# Test set: Average loss: 1.1594
# [31,  100] loss:0.626
# [31,  200] loss:0.523
# Test set: Average loss: 1.2773
# [32,  100] loss:0.569
# [32,  200] loss:0.541
# Test set: Average loss: 0.9913
# [33,  100] loss:0.460
# [33,  200] loss:0.674
# Test set: Average loss: 1.1235
# [34,  100] loss:0.611
# [34,  200] loss:0.658
# Test set: Average loss: 0.9579
# [35,  100] loss:0.502
# [35,  200] loss:0.520
# Test set: Average loss: 0.9872
# [36,  100] loss:0.531
# [36,  200] loss:0.514
# Test set: Average loss: 1.1576
# [37,  100] loss:0.503
# [37,  200] loss:0.570
# Test set: Average loss: 1.0883
# [38,  100] loss:0.525
# [38,  200] loss:0.438
# Test set: Average loss: 1.0540
# [39,  100] loss:0.507
# [39,  200] loss:0.491
# Test set: Average loss: 0.9969
# [40,  100] loss:0.517
# [40,  200] loss:0.437
# Test set: Average loss: 1.0471
# [41,  100] loss:0.592
# [41,  200] loss:0.427
# Test set: Average loss: 1.0298
# [42,  100] loss:0.579
# [42,  200] loss:0.452
# Test set: Average loss: 1.1475
# [43,  100] loss:0.478
# [43,  200] loss:0.561
# Test set: Average loss: 1.0555
# [44,  100] loss:0.461
# [44,  200] loss:0.578
# Test set: Average loss: 1.2366
# [45,  100] loss:0.420
# [45,  200] loss:0.550
# Test set: Average loss: 1.0735
# [46,  100] loss:0.557
# [46,  200] loss:0.492
# Test set: Average loss: 1.1680
# [47,  100] loss:0.459
# [47,  200] loss:0.525
# Test set: Average loss: 1.0672
# [48,  100] loss:0.423
# [48,  200] loss:0.500
# Test set: Average loss: 0.9801
# [49,  100] loss:0.624
# [49,  200] loss:0.416
# Test set: Average loss: 1.2461
# [50,  100] loss:0.591
# [50,  200] loss:0.550
# Test set: Average loss: 1.1245
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.370
# [1,  200] loss:0.478
# Test set: Average loss: 1.0551
# [2,  100] loss:0.501
# [2,  200] loss:0.505
# Test set: Average loss: 1.1209
# [3,  100] loss:0.497
# [3,  200] loss:0.514
# Test set: Average loss: 1.1534
# [4,  100] loss:0.569
# [4,  200] loss:0.466
# Test set: Average loss: 1.1582
# [5,  100] loss:0.423
# [5,  200] loss:0.552
# Test set: Average loss: 1.1927
# [6,  100] loss:0.518
# [6,  200] loss:0.439
# Test set: Average loss: 1.1147
# [7,  100] loss:0.555
# [7,  200] loss:0.466
# Test set: Average loss: 1.1561
# [8,  100] loss:0.553
# [8,  200] loss:0.489
# Test set: Average loss: 1.0617
# [9,  100] loss:0.594
# [9,  200] loss:0.437
# Test set: Average loss: 0.9594
# [10,  100] loss:0.429
# [10,  200] loss:0.492
# Test set: Average loss: 1.0799
# [11,  100] loss:0.374
# [11,  200] loss:0.414
# Test set: Average loss: 1.1861
# [12,  100] loss:0.407
# [12,  200] loss:0.383
# Test set: Average loss: 1.1623
# [13,  100] loss:0.459
# [13,  200] loss:0.341
# Test set: Average loss: 1.2888
# [14,  100] loss:0.498
# [14,  200] loss:0.416
# Test set: Average loss: 1.1717
# [15,  100] loss:0.548
# [15,  200] loss:0.517
# Test set: Average loss: 1.2675
# [16,  100] loss:0.498
# [16,  200] loss:0.373
# Test set: Average loss: 1.4442
# [17,  100] loss:0.327
# [17,  200] loss:0.534
# Test set: Average loss: 1.1062
# [18,  100] loss:0.442
# [18,  200] loss:0.417
# Test set: Average loss: 1.2188
# [19,  100] loss:0.385
# [19,  200] loss:0.395
# Test set: Average loss: 1.3759
# [20,  100] loss:0.493
# [20,  200] loss:0.424
# Test set: Average loss: 1.1929
# [21,  100] loss:0.420
# [21,  200] loss:0.543
# Test set: Average loss: 1.0247
# [22,  100] loss:0.498
# [22,  200] loss:0.331
# Test set: Average loss: 1.1157
# [23,  100] loss:0.470
# [23,  200] loss:0.326
# Test set: Average loss: 1.0260
# [24,  100] loss:0.429
# [24,  200] loss:0.395
# Test set: Average loss: 1.3242
# [25,  100] loss:0.386
# [25,  200] loss:0.406
# Test set: Average loss: 1.2353
# [26,  100] loss:0.393
# [26,  200] loss:0.461
# Test set: Average loss: 1.4275
# [27,  100] loss:0.411
# [27,  200] loss:0.535
# Test set: Average loss: 1.1762
# [28,  100] loss:0.426
# [28,  200] loss:0.409
# Test set: Average loss: 1.2003
# [29,  100] loss:0.335
# [29,  200] loss:0.425
# Test set: Average loss: 1.2507
# [30,  100] loss:0.498
# [30,  200] loss:0.339
# Test set: Average loss: 1.2829
# [31,  100] loss:0.405
# [31,  200] loss:0.447
# Test set: Average loss: 1.2894
# [32,  100] loss:0.453
# [32,  200] loss:0.327
# Test set: Average loss: 1.3959
# [33,  100] loss:0.361
# [33,  200] loss:0.390
# Test set: Average loss: 1.3703
# [34,  100] loss:0.355
# [34,  200] loss:0.336
# Test set: Average loss: 1.3686
# [35,  100] loss:0.425
# [35,  200] loss:0.352
# Test set: Average loss: 1.3470
# [36,  100] loss:0.430
# [36,  200] loss:0.429
# Test set: Average loss: 1.2746
# [37,  100] loss:0.444
# [37,  200] loss:0.370
# Test set: Average loss: 1.2566
# [38,  100] loss:0.470
# [38,  200] loss:0.356
# Test set: Average loss: 1.4746
# [39,  100] loss:0.468
# [39,  200] loss:0.353
# Test set: Average loss: 1.2885
# [40,  100] loss:0.335
# [40,  200] loss:0.410
# Test set: Average loss: 1.2734
# [41,  100] loss:0.459
# [41,  200] loss:0.394
# Test set: Average loss: 1.3837
# [42,  100] loss:0.449
# [42,  200] loss:0.293
# Test set: Average loss: 1.2558
# [43,  100] loss:0.287
# [43,  200] loss:0.368
# Test set: Average loss: 1.2620
# [44,  100] loss:0.267
# [44,  200] loss:0.430
# Test set: Average loss: 1.2867
# [45,  100] loss:0.343
# [45,  200] loss:0.418
# Test set: Average loss: 1.4230
# [46,  100] loss:0.476
# [46,  200] loss:0.284
# Test set: Average loss: 1.5045
# [47,  100] loss:0.435
# [47,  200] loss:0.387
# Test set: Average loss: 1.2630
# [48,  100] loss:0.389
# [48,  200] loss:0.319
# Test set: Average loss: 1.2879
# [49,  100] loss:0.385
# [49,  200] loss:0.343
# Test set: Average loss: 1.5018
# [50,  100] loss:0.336
# [50,  200] loss:0.442
# Test set: Average loss: 1.2612
# Finished Training

# %%
#训练150个epoch的测试精度
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast1.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：72%
# 测试集中不标准动作图片的预测精度为：67%
# 测试集中标准动作图片的预测精度为：78%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     21   10
# 1.0      6   22
