# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''图片数据集载入'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/train/goddess'
test_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/test/goddess'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset1 = data1+data2+data3+data4+data5+data6+data7+data8
testset1 = torchvision.datasets.ImageFolder(root=test_path,transform=transform1)

# %%
'''骨架坐标点数据集载入'''
import torch
import pandas as pd
import numpy as np
df = pd.read_excel("/content/drive/MyDrive/yoga/landmarks/goddess_train_landmarks.xlsx")
#df = df[df['体式']=='downdog']
df.loc[df['标准/不标准']=='nonstandard', '是否标准编号'] = 0
df.loc[df['标准/不标准']=='standard', '是否标准编号'] = 1
df.drop(["编号", '体式', '标准/不标准'],axis=1, inplace=True)
#print(df)
dataset_train = df.values
dataset_train = np.array(dataset_train)
X_train = dataset_train[:,:-1].astype(float)
Y_train = dataset_train[:,-1:].astype(int).squeeze(-1)
X_train, Y_train = torch.Tensor(X_train),torch.LongTensor(Y_train) 
#print(X_train, Y_train)
df = pd.read_excel("/content/drive/MyDrive/yoga/landmarks/goddess_test_landmarks.xlsx")
#df = df[df['体式']=='downdog']
df.loc[df['标准/不标准']=='nonstandard', '是否标准编号'] = 0
df.loc[df['标准/不标准']=='standard', '是否标准编号'] = 1
df.drop(["编号", '体式', '标准/不标准'],axis=1, inplace=True)
dataset_test = df.values
dataset_test = np.array(dataset_test)
X_test = dataset_test[:,:-1].astype(float)
Y_test = dataset_test[:,-1:].astype(int).squeeze(-1)
X_test, Y_test = torch.Tensor(X_test),torch.LongTensor(Y_test)
#print(X_test, Y_test)
trainset2_data =  torch.utils.data.TensorDataset(X_train,Y_train)
trainset2 = trainset2_data+trainset2_data+trainset2_data+trainset2_data+trainset2_data+trainset2_data+trainset2_data+trainset2_data
testset2 = torch.utils.data.TensorDataset(X_test,Y_test)

# %%
'''训练集合并'''
import numpy as np
import torch.utils.data as data
list_x_train = []
list_y_train = []
for i in range(len(trainset1)):
  set1 = torch.flatten(trainset1[i][0])
  set = torch.cat([set1, trainset2[i][0]],0)
  list_x_train.append(set)
  list_y_train.append(trainset1[i][1])
x_train = np.array(list_x_train)
y_train = np.array(list_y_train)
print(x_train)
print(y_train)
class Mydataset(data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.idx = list()
        for item in x:
            self.idx.append(item)
        pass
    def __getitem__(self, index):
        input_data = self.idx[index] #可继续进行数据增强，这里没有进行数据增强操作
        target = self.y[index]
        return input_data, target
    def __len__(self):
        return len(self.idx)
trainset = Mydataset(x_train,y_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=4, shuffle=True)
# Out:
# [tensor([1.8431e-01, 1.4510e-01, 9.0196e-02,  ..., 5.2293e+01, 2.1616e+02,
#          3.1712e+01])
#  tensor([ -0.7647,  -0.7569,  -0.7490,  ...,  37.3002, 579.3256, -49.2973])
#  tensor([  1.0000,   1.0000,   1.0000,  ..., 287.3958, 380.6423, -71.2762])
#  ...
#  tensor([  1.0000,   1.0000,   1.0000,  ..., 197.2209, 532.5213, -69.2885])
#  tensor([-1.1765e-02,  1.1373e-01, -3.9216e-03,  ...,  2.3346e+02,
#           4.0619e+02,  3.9216e+00])
#  tensor([  0.8902,   0.8902,   0.8980,  ...,  17.0536, 260.4667, -41.4462])]
# [0 0 0 ... 1 1 1]
# <ipython-input-4-3d8bbbd1a5d6>:11: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   x_train = np.array(list_x_train)
# <ipython-input-4-3d8bbbd1a5d6>:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_train = np.array(list_x_train)

# %%
torch.save(trainset,"/content/drive/MyDrive/yoga/datasets/eva_goddess2_trainset.pt" )

# %%
'''测试集合并'''
import numpy as np
import torch.utils.data as data
list_x_test = []
list_y_test = []
for i in range(len(testset1)):
  set1 = torch.flatten(testset1[i][0])
  set = torch.cat([set1, testset2[i][0]],0)
  list_x_test.append(set)
  list_y_test.append(testset1[i][1])
x_test = np.array(list_x_test)
y_test = np.array(list_y_test)
testset = Mydataset(x_test,y_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=4, shuffle=False)
# Out:
# <ipython-input-6-eda196c4da7c>:11: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   x_test = np.array(list_x_test)
# <ipython-input-6-eda196c4da7c>:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_test = np.array(list_x_test)

# %%
torch.save(testset,"/content/drive/MyDrive/yoga/datasets/eva_goddess2_testset.pt" )

# %%
import torch.utils.data as data
class Mydataset(data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.idx = list()
        for item in x:
            self.idx.append(item)
        pass
    def __getitem__(self, index):
        input_data = self.idx[index] #可继续进行数据增强，这里没有进行数据增强操作
        target = self.y[index]
        return input_data, target
    def __len__(self):
        return len(self.idx)
trainset = torch.load("/content/drive/MyDrive/yoga/datasets/eva_goddess2_trainset.pt")
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=4, shuffle=True)

# %%
testset = torch.load("/content/drive/MyDrive/yoga/datasets/eva_goddess2_testset.pt")
testloader = torch.utils.data.DataLoader(
    testset, batch_size=4, shuffle=False)

# %%
'''MLP网络'''
import torch.nn as nn
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.all = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.Linear(hidden_size, num_classes)
        )
    def forward(self, x):
        out = self.all(x)
        return out

# %%
'''VGG19与MLP网络全连接层拼接网络'''
import torch.nn as nn
import torchvision.models as models
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier = nn.Sequential(*list(vgg19.classifier.children())[:-1])  
mlp_pre = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast2.pkl')
mlp_pre.all =nn.Sequential(*list(mlp_pre.all.children())[:-1])
class fusionnet(nn.Module):
    def __init__(self, num_class=2):
        super().__init__()
        self.vgg = vgg19
        self.mlp = mlp_pre
        self.fc_out = nn.Linear(67 + 4096, num_class)
    def forward(self, x):
        #print(x.size())
        x1 = x[..., :128*128*3]
        x1 = torch.reshape(x1, (-1,3,128,128))
        #print(x1.shape)
        x2 = x[..., 128*128*3:]
        #print(x2.shape)
        x1 = self.vgg(x1)
        x2 = self.mlp(x2)
        #print(x1.shape)
        #print(x2.shape)
        out = torch.concat([x1,x2], 1)
        output = self.fc_out(out)
        return output
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss2.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss2.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss2.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss2.csv',index=False)

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(fusionnet().to(device))
# Out:
# 测试集精度为：35%
# 测试集中不标准动作图片的预测精度为：38%
# 测试集中标准动作图片的预测精度为：32%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     12   19
# 1.0     19    9

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(fusionnet().to(device),50,100)
# Out:
# [1,  100] loss:4.335
# [1,  200] loss:3.635
# Test set: Average loss: 1.3126
# [2,  100] loss:2.690
# [2,  200] loss:2.808
# Test set: Average loss: 1.3400
# [3,  100] loss:2.845
# [3,  200] loss:2.545
# Test set: Average loss: 0.8768
# [4,  100] loss:2.124
# [4,  200] loss:2.550
# Test set: Average loss: 1.5214
# [5,  100] loss:2.279
# [5,  200] loss:2.297
# Test set: Average loss: 1.2624
# [6,  100] loss:2.263
# [6,  200] loss:1.875
# Test set: Average loss: 1.3956
# [7,  100] loss:1.959
# [7,  200] loss:2.153
# Test set: Average loss: 1.0872
# [8,  100] loss:1.910
# [8,  200] loss:1.970
# Test set: Average loss: 1.1684
# [9,  100] loss:1.821
# [9,  200] loss:1.818
# Test set: Average loss: 0.7476
# [10,  100] loss:1.752
# [10,  200] loss:1.743
# Test set: Average loss: 1.1789
# [11,  100] loss:1.717
# [11,  200] loss:1.945
# Test set: Average loss: 1.0361
# [12,  100] loss:1.498
# [12,  200] loss:1.494
# Test set: Average loss: 0.9830
# [13,  100] loss:1.791
# [13,  200] loss:1.650
# Test set: Average loss: 1.1976
# [14,  100] loss:1.561
# [14,  200] loss:1.598
# Test set: Average loss: 1.3043
# [15,  100] loss:1.628
# [15,  200] loss:1.392
# Test set: Average loss: 0.8612
# [16,  100] loss:1.349
# [16,  200] loss:1.412
# Test set: Average loss: 0.9199
# [17,  100] loss:1.339
# [17,  200] loss:1.419
# Test set: Average loss: 1.3914
# [18,  100] loss:1.195
# [18,  200] loss:1.707
# Test set: Average loss: 1.2785
# [19,  100] loss:1.450
# [19,  200] loss:1.434
# Test set: Average loss: 0.8213
# [20,  100] loss:1.234
# [20,  200] loss:1.275
# Test set: Average loss: 1.2500
# [21,  100] loss:1.431
# [21,  200] loss:1.260
# Test set: Average loss: 1.1542
# [22,  100] loss:1.051
# [22,  200] loss:1.120
# Test set: Average loss: 1.1410
# [23,  100] loss:1.158
# [23,  200] loss:1.137
# Test set: Average loss: 0.8924
# [24,  100] loss:1.111
# [24,  200] loss:1.293
# Test set: Average loss: 1.1379
# [25,  100] loss:1.149
# [25,  200] loss:1.173
# Test set: Average loss: 0.8935
# [26,  100] loss:1.149
# [26,  200] loss:1.166
# Test set: Average loss: 0.9778
# [27,  100] loss:1.162
# [27,  200] loss:1.032
# Test set: Average loss: 1.1929
# [28,  100] loss:0.890
# [28,  200] loss:0.894
# Test set: Average loss: 0.9810
# [29,  100] loss:1.024
# [29,  200] loss:0.960
# Test set: Average loss: 1.0823
# [30,  100] loss:1.021
# [30,  200] loss:0.979
# Test set: Average loss: 1.0922
# [31,  100] loss:1.089
# [31,  200] loss:0.954
# Test set: Average loss: 1.6049
# [32,  100] loss:0.886
# [32,  200] loss:0.856
# Test set: Average loss: 1.2215
# [33,  100] loss:0.927
# [33,  200] loss:0.878
# Test set: Average loss: 1.1755
# [34,  100] loss:0.873
# [34,  200] loss:0.798
# Test set: Average loss: 0.9667
# [35,  100] loss:0.876
# [35,  200] loss:0.853
# Test set: Average loss: 1.3440
# [36,  100] loss:0.760
# [36,  200] loss:0.983
# Test set: Average loss: 0.9415
# [37,  100] loss:0.830
# [37,  200] loss:0.734
# Test set: Average loss: 1.5355
# [38,  100] loss:0.728
# [38,  200] loss:0.946
# Test set: Average loss: 1.4332
# [39,  100] loss:0.752
# [39,  200] loss:0.768
# Test set: Average loss: 1.3120
# [40,  100] loss:0.704
# [40,  200] loss:0.774
# Test set: Average loss: 1.5207
# [41,  100] loss:0.687
# [41,  200] loss:0.727
# Test set: Average loss: 1.1623
# [42,  100] loss:0.714
# [42,  200] loss:0.809
# Test set: Average loss: 0.8385
# [43,  100] loss:0.746
# [43,  200] loss:0.712
# Test set: Average loss: 1.0756
# [44,  100] loss:0.692
# [44,  200] loss:0.716
# Test set: Average loss: 0.8120
# [45,  100] loss:0.569
# [45,  200] loss:0.640
# Test set: Average loss: 0.9716
# [46,  100] loss:0.517
# [46,  200] loss:0.692
# Test set: Average loss: 1.2432
# [47,  100] loss:0.540
# [47,  200] loss:0.582
# Test set: Average loss: 1.4227
# [48,  100] loss:0.640
# [48,  200] loss:0.584
# Test set: Average loss: 1.1789
# [49,  100] loss:0.681
# [49,  200] loss:0.626
# Test set: Average loss: 1.1350
# [50,  100] loss:0.597
# [50,  200] loss:0.484
# Test set: Average loss: 1.5286
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess2.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.621
# [1,  200] loss:0.563
# Test set: Average loss: 1.3042
# [2,  100] loss:0.682
# [2,  200] loss:0.707
# Test set: Average loss: 1.2071
# [3,  100] loss:0.596
# [3,  200] loss:0.560
# Test set: Average loss: 1.5980
# [4,  100] loss:0.643
# [4,  200] loss:0.478
# Test set: Average loss: 1.1510
# [5,  100] loss:0.549
# [5,  200] loss:0.502
# Test set: Average loss: 1.1337
# [6,  100] loss:0.522
# [6,  200] loss:0.632
# Test set: Average loss: 1.1931
# [7,  100] loss:0.487
# [7,  200] loss:0.578
# Test set: Average loss: 0.7165
# [8,  100] loss:0.473
# [8,  200] loss:0.508
# Test set: Average loss: 1.6557
# [9,  100] loss:0.473
# [9,  200] loss:0.538
# Test set: Average loss: 1.5697
# [10,  100] loss:0.560
# [10,  200] loss:0.530
# Test set: Average loss: 1.4310
# [11,  100] loss:0.414
# [11,  200] loss:0.592
# Test set: Average loss: 1.4280
# [12,  100] loss:0.419
# [12,  200] loss:0.460
# Test set: Average loss: 0.9547
# [13,  100] loss:0.349
# [13,  200] loss:0.385
# Test set: Average loss: 1.6952
# [14,  100] loss:0.372
# [14,  200] loss:0.415
# Test set: Average loss: 1.7316
# [15,  100] loss:0.348
# [15,  200] loss:0.495
# Test set: Average loss: 2.0283
# [16,  100] loss:0.382
# [16,  200] loss:0.456
# Test set: Average loss: 1.6636
# [17,  100] loss:0.428
# [17,  200] loss:0.555
# Test set: Average loss: 1.5175
# [18,  100] loss:0.413
# [18,  200] loss:0.522
# Test set: Average loss: 1.0112
# [19,  100] loss:0.451
# [19,  200] loss:0.447
# Test set: Average loss: 1.0650
# [20,  100] loss:0.375
# [20,  200] loss:0.561
# Test set: Average loss: 1.5944
# [21,  100] loss:0.361
# [21,  200] loss:0.427
# Test set: Average loss: 1.1972
# [22,  100] loss:0.378
# [22,  200] loss:0.469
# Test set: Average loss: 1.1083
# [23,  100] loss:0.344
# [23,  200] loss:0.380
# Test set: Average loss: 1.3996
# [24,  100] loss:0.420
# [24,  200] loss:0.419
# Test set: Average loss: 1.1388
# [25,  100] loss:0.394
# [25,  200] loss:0.328
# Test set: Average loss: 1.1730
# [26,  100] loss:0.365
# [26,  200] loss:0.302
# Test set: Average loss: 1.5968
# [27,  100] loss:0.272
# [27,  200] loss:0.355
# Test set: Average loss: 1.8235
# [28,  100] loss:0.279
# [28,  200] loss:0.341
# Test set: Average loss: 1.8924
# [29,  100] loss:0.298
# [29,  200] loss:0.305
# Test set: Average loss: 1.6398
# [30,  100] loss:0.401
# [30,  200] loss:0.317
# Test set: Average loss: 1.7164
# [31,  100] loss:0.372
# [31,  200] loss:0.264
# Test set: Average loss: 1.9897
# [32,  100] loss:0.320
# [32,  200] loss:0.320
# Test set: Average loss: 1.2383
# [33,  100] loss:0.289
# [33,  200] loss:0.328
# Test set: Average loss: 1.4677
# [34,  100] loss:0.303
# [34,  200] loss:0.386
# Test set: Average loss: 1.0506
# [35,  100] loss:0.303
# [35,  200] loss:0.457
# Test set: Average loss: 1.2720
# [36,  100] loss:0.301
# [36,  200] loss:0.283
# Test set: Average loss: 1.8286
# [37,  100] loss:0.291
# [37,  200] loss:0.360
# Test set: Average loss: 1.5771
# [38,  100] loss:0.315
# [38,  200] loss:0.320
# Test set: Average loss: 1.3429
# [39,  100] loss:0.320
# [39,  200] loss:0.365
# Test set: Average loss: 1.9338
# [40,  100] loss:0.233
# [40,  200] loss:0.289
# Test set: Average loss: 1.7149
# [41,  100] loss:0.217
# [41,  200] loss:0.222
# Test set: Average loss: 1.2777
# [42,  100] loss:0.288
# [42,  200] loss:0.220
# Test set: Average loss: 1.5327
# [43,  100] loss:0.310
# [43,  200] loss:0.219
# Test set: Average loss: 1.3467
# [44,  100] loss:0.328
# [44,  200] loss:0.301
# Test set: Average loss: 1.8001
# [45,  100] loss:0.245
# [45,  200] loss:0.228
# Test set: Average loss: 2.1818
# [46,  100] loss:0.364
# [46,  200] loss:0.269
# Test set: Average loss: 1.9000
# [47,  100] loss:0.318
# [47,  200] loss:0.217
# Test set: Average loss: 1.3497
# [48,  100] loss:0.242
# [48,  200] loss:0.284
# Test set: Average loss: 1.7267
# [49,  100] loss:0.218
# [49,  200] loss:0.229
# Test set: Average loss: 1.4741
# [50,  100] loss:0.241
# [50,  200] loss:0.212
# Test set: Average loss: 1.9142
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess2.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.293
# [1,  200] loss:0.386
# Test set: Average loss: 1.5228
# [2,  100] loss:0.308
# [2,  200] loss:0.259
# Test set: Average loss: 1.4288
# [3,  100] loss:0.229
# [3,  200] loss:0.223
# Test set: Average loss: 2.0737
# [4,  100] loss:0.245
# [4,  200] loss:0.146
# Test set: Average loss: 1.6604
# [5,  100] loss:0.217
# [5,  200] loss:0.323
# Test set: Average loss: 1.7584
# [6,  100] loss:0.304
# [6,  200] loss:0.277
# Test set: Average loss: 1.8177
# [7,  100] loss:0.165
# [7,  200] loss:0.280
# Test set: Average loss: 1.3554
# [8,  100] loss:0.230
# [8,  200] loss:0.214
# Test set: Average loss: 1.6720
# [9,  100] loss:0.191
# [9,  200] loss:0.284
# Test set: Average loss: 1.7304
# [10,  100] loss:0.295
# [10,  200] loss:0.278
# Test set: Average loss: 2.3014
# [11,  100] loss:0.268
# [11,  200] loss:0.164
# Test set: Average loss: 1.6631
# [12,  100] loss:0.189
# [12,  200] loss:0.192
# Test set: Average loss: 2.1517
# [13,  100] loss:0.205
# [13,  200] loss:0.236
# Test set: Average loss: 2.0915
# [14,  100] loss:0.250
# [14,  200] loss:0.212
# Test set: Average loss: 1.8876
# [15,  100] loss:0.155
# [15,  200] loss:0.197
# Test set: Average loss: 1.4347
# [16,  100] loss:0.160
# [16,  200] loss:0.158
# Test set: Average loss: 2.2773
# [17,  100] loss:0.168
# [17,  200] loss:0.143
# Test set: Average loss: 1.7221
# [18,  100] loss:0.202
# [18,  200] loss:0.176
# Test set: Average loss: 1.8695
# [19,  100] loss:0.228
# [19,  200] loss:0.241
# Test set: Average loss: 2.2588
# [20,  100] loss:0.261
# [20,  200] loss:0.302
# Test set: Average loss: 1.6723
# [21,  100] loss:0.134
# [21,  200] loss:0.241
# Test set: Average loss: 1.9210
# [22,  100] loss:0.206
# [22,  200] loss:0.156
# Test set: Average loss: 1.7226
# [23,  100] loss:0.238
# [23,  200] loss:0.171
# Test set: Average loss: 1.2453
# [24,  100] loss:0.192
# [24,  200] loss:0.181
# Test set: Average loss: 1.3648
# [25,  100] loss:0.142
# [25,  200] loss:0.162
# Test set: Average loss: 1.7779
# [26,  100] loss:0.158
# [26,  200] loss:0.193
# Test set: Average loss: 1.7913
# [27,  100] loss:0.228
# [27,  200] loss:0.194
# Test set: Average loss: 1.6863
# [28,  100] loss:0.174
# [28,  200] loss:0.241
# Test set: Average loss: 2.0170
# [29,  100] loss:0.152
# [29,  200] loss:0.169
# Test set: Average loss: 1.4597
# [30,  100] loss:0.134
# [30,  200] loss:0.169
# Test set: Average loss: 2.3917
# [31,  100] loss:0.183
# [31,  200] loss:0.208
# Test set: Average loss: 1.9689
# [32,  100] loss:0.174
# [32,  200] loss:0.168
# Test set: Average loss: 2.3718
# [33,  100] loss:0.117
# [33,  200] loss:0.179
# Test set: Average loss: 2.1860
# [34,  100] loss:0.161
# [34,  200] loss:0.184
# Test set: Average loss: 1.1921
# [35,  100] loss:0.141
# [35,  200] loss:0.161
# Test set: Average loss: 1.9123
# [36,  100] loss:0.158
# [36,  200] loss:0.157
# Test set: Average loss: 1.8561
# [37,  100] loss:0.147
# [37,  200] loss:0.196
# Test set: Average loss: 1.4646
# [38,  100] loss:0.111
# [38,  200] loss:0.191
# Test set: Average loss: 1.6013
# [39,  100] loss:0.099
# [39,  200] loss:0.174
# Test set: Average loss: 2.3189
# [40,  100] loss:0.200
# [40,  200] loss:0.166
# Test set: Average loss: 1.9120
# [41,  100] loss:0.136
# [41,  200] loss:0.184
# Test set: Average loss: 1.7420
# [42,  100] loss:0.197
# [42,  200] loss:0.187
# Test set: Average loss: 2.3423
# [43,  100] loss:0.133
# [43,  200] loss:0.211
# Test set: Average loss: 1.6489
# [44,  100] loss:0.136
# [44,  200] loss:0.141
# Test set: Average loss: 1.6251
# [45,  100] loss:0.134
# [45,  200] loss:0.131
# Test set: Average loss: 1.7787
# [46,  100] loss:0.141
# [46,  200] loss:0.154
# Test set: Average loss: 2.3141
# [47,  100] loss:0.153
# [47,  200] loss:0.143
# Test set: Average loss: 1.7572
# [48,  100] loss:0.154
# [48,  200] loss:0.127
# Test set: Average loss: 2.2642
# [49,  100] loss:0.112
# [49,  200] loss:0.141
# Test set: Average loss: 1.8936
# [50,  100] loss:0.223
# [50,  200] loss:0.111
# Test set: Average loss: 2.1927
# Finished Training

# %%
#训练150个epoch的测试精度
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess2.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：72%
# 测试集中不标准动作图片的预测精度为：70%
# 测试集中标准动作图片的预测精度为：75%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     22    9
# 1.0      7   21
