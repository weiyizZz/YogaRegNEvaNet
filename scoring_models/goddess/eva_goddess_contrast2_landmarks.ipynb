# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架坐标点数据集载入'''
import torch
import pandas as pd
import numpy as np
df = pd.read_csv("/content/drive/MyDrive/yoga/landmarks/train_landmarks.csv",encoding='gbk')
df = df[df['体式']=='goddess']
df.loc[df['标准/不标准']=='nonstandard', '是否标准编号'] = 0
df.loc[df['标准/不标准']=='standard', '是否标准编号'] = 1
df.drop(["编号", '体式', '标准/不标准'],axis=1, inplace=True)
#print(df)
dataset_train = df.values
dataset_train = np.array(dataset_train)
X_train = dataset_train[:,:-1].astype(float)
Y_train = dataset_train[:,-1:].astype(int).squeeze(-1)
X_train, Y_train = torch.Tensor(X_train),torch.LongTensor(Y_train) 
#print(X_train, Y_train)
df = pd.read_csv("/content/drive/MyDrive/yoga/landmarks/test_landmarks.csv",encoding='gbk')
df = df[df['体式']=='goddess']
df.loc[df['标准/不标准']=='nonstandard', '是否标准编号'] = 0
df.loc[df['标准/不标准']=='standard', '是否标准编号'] = 1
df.drop(["编号", '体式', '标准/不标准'],axis=1, inplace=True)
dataset_test = df.values
dataset_test = np.array(dataset_test)
X_test = dataset_test[:,:-1].astype(float)
Y_test = dataset_test[:,-1:].astype(int).squeeze(-1)
X_test, Y_test = torch.Tensor(X_test),torch.LongTensor(Y_test)
#print(X_test, Y_test)
trainset =  torch.utils.data.TensorDataset(X_train,Y_train)
testset = torch.utils.data.TensorDataset(X_test,Y_test)
BATCH_SIZE = 4
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)

# %%
'''MLP网络'''
import torch.nn as nn
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.all = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.Linear(hidden_size, num_classes)
        )
    def forward(self, x):
        out = self.all(x)
        return out
class NeuralNet2(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet2, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, 60)
        self.fc3 = nn.Linear(60, 30)
        self.fc4 = nn.Linear(30, num_classes)
        self.dropout = nn.Dropout(p=0.5)
    def forward(self, x):
        out = self.fc1(x)
        out = self.dropout(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.dropout(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.dropout(out)
        out = self.relu(out)
        out = self.fc4(out)
        return out

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast2.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([])
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test, pred_y))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast2.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast2.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast2.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_contrast2.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_contrast2.csv',index=False)

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(NeuralNet(input_size=99, hidden_size=67, num_classes=2).to(device),2000,15)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# [334,   30] loss:0.701
# Test set: Average loss: 0.4276
# [335,   15] loss:0.972
# [335,   30] loss:1.068
# Test set: Average loss: 0.4402
# [336,   15] loss:1.127
# [336,   30] loss:0.903
# Test set: Average loss: 0.3610
# [337,   15] loss:0.468
# [337,   30] loss:1.125
# Test set: Average loss: 0.5934
# [338,   15] loss:1.003
# [338,   30] loss:0.871
# Test set: Average loss: 0.3479
# [339,   15] loss:0.986
# [339,   30] loss:1.149
# Test set: Average loss: 0.5100
# [340,   15] loss:1.025
# [340,   30] loss:1.003
# Test set: Average loss: 0.4725
# [341,   15] loss:0.825
# [341,   30] loss:1.055
# Test set: Average loss: 0.5104
# [342,   15] loss:1.069
# [342,   30] loss:1.159
# Test set: Average loss: 0.6072
# [343,   15] loss:0.937
# [343,   30] loss:0.523
# Test set: Average loss: 0.3988
# [344,   15] loss:0.609
# [344,   30] loss:0.703
# Test set: Average loss: 0.4583
# [345,   15] loss:0.854
# [345,   30] loss:0.894
# Test set: Average loss: 0.5576
# [346,   15] loss:0.778
# [346,   30] loss:0.827
# Test set: Average loss: 0.4147
# [347,   15] loss:1.053
# [347,   30] loss:1.017
# Test set: Average loss: 0.5709
# [348,   15] loss:0.931
# [348,   30] loss:1.012
# Test set: Average loss: 0.4103
# [349,   15] loss:0.823
# [349,   30] loss:0.727
# Test set: Average loss: 0.1781
# [350,   15] loss:0.644
# [350,   30] loss:0.999
# Test set: Average loss: 0.4773
# [351,   15] loss:0.963
# [351,   30] loss:0.572
# Test set: Average loss: 0.4742
# [352,   15] loss:0.760
# [352,   30] loss:0.895
# Test set: Average loss: 0.4310
# [353,   15] loss:0.640
# [353,   30] loss:0.867
# Test set: Average loss: 0.5547
# [354,   15] loss:1.107
# [354,   30] loss:0.851
# Test set: Average loss: 0.4464
# [355,   15] loss:1.049
# [355,   30] loss:0.932
# Test set: Average loss: 0.5472
# [356,   15] loss:1.526
# [356,   30] loss:0.659
# Test set: Average loss: 0.6310
# Test set: Average loss: 0.3415
# [872,   15] loss:0.693
# [872,   30] loss:0.627
# Test set: Average loss: 0.3262
# [873,   15] loss:0.565
# [873,   30] loss:0.518
# Test set: Average loss: 0.5399
# [874,   15] loss:0.728
# [874,   30] loss:0.484
# Test set: Average loss: 0.2973
# [875,   15] loss:0.691
# [875,   30] loss:0.546
# Test set: Average loss: 0.4950
# [876,   15] loss:0.591
# [876,   30] loss:0.499
# Test set: Average loss: 0.3769
# [877,   15] loss:0.573
# [877,   30] loss:0.511
# Test set: Average loss: 0.4319
# [878,   15] loss:0.598
# [878,   30] loss:0.559
# Test set: Average loss: 0.5387
# [879,   15] loss:0.607
# [879,   30] loss:0.643
# Test set: Average loss: 0.6099
# [880,   15] loss:0.523
# [880,   30] loss:0.583
# Test set: Average loss: 0.3060
# [881,   15] loss:0.574
# [881,   30] loss:0.538
# Test set: Average loss: 0.6153
# [882,   15] loss:0.520
# [882,   30] loss:0.591
# Test set: Average loss: 0.1844
# [883,   15] loss:0.404
# [883,   30] loss:0.706
# Test set: Average loss: 0.3384
# [884,   15] loss:0.595
# [884,   30] loss:0.596
# Test set: Average loss: 0.2978
# [885,   15] loss:0.475
# [885,   30] loss:0.567
# Test set: Average loss: 0.5945
# [886,   15] loss:0.541
# [886,   30] loss:0.658
# Test set: Average loss: 0.3063
# [887,   15] loss:0.644
# [887,   30] loss:0.891
# Test set: Average loss: 0.3561
# [888,   15] loss:0.575
# [888,   30] loss:0.748
# Test set: Average loss: 0.3710
# [889,   15] loss:0.549
# [889,   30] loss:0.555
# Test set: Average loss: 0.3779
# [890,   15] loss:0.490
# [890,   30] loss:0.480
# Test set: Average loss: 0.5505
# [891,   15] loss:0.516
# [891,   30] loss:0.554
# Test set: Average loss: 0.5013
# [892,   15] loss:0.465
# [892,   30] loss:0.647
# Test set: Average loss: 0.2857
# [893,   15] loss:0.688
# [893,   30] loss:0.670
# Test set: Average loss: 0.4172
# [894,   15] loss:0.675
# [894,   30] loss:0.436
# Test set: Average loss: 0.5523
# [895,   15] loss:0.600
# [895,   30] loss:0.588
# Test set: Average loss: 0.3746
# [896,   15] loss:0.692
# [896,   30] loss:0.505
# Test set: Average loss: 0.3958
# [897,   15] loss:0.634
# [897,   30] loss:0.505
# Test set: Average loss: 0.3467
# [898,   15] loss:0.631
# [898,   30] loss:0.579
# Test set: Average loss: 0.3924
# [899,   15] loss:0.383
# [899,   30] loss:0.529
# Test set: Average loss: 0.3209
# [900,   15] loss:0.729
# [900,   30] loss:0.740
# Test set: Average loss: 0.2486
# [901,   15] loss:0.561
# [901,   30] loss:0.512
# Test set: Average loss: 0.3625
# [902,   15] loss:0.416
# [902,   30] loss:0.519
# Test set: Average loss: 0.3708
# [903,   15] loss:0.547
# [903,   30] loss:0.598
# Test set: Average loss: 0.3418
# [904,   15] loss:0.570
# [904,   30] loss:0.657
# Test set: Average loss: 0.3550
# [905,   15] loss:0.570
# [905,   30] loss:0.448
# [1979,   30] loss:0.442
# Test set: Average loss: 0.3852
# [1980,   15] loss:0.541
# [1980,   30] loss:0.507
# Test set: Average loss: 0.3519
# [1981,   15] loss:0.509
# [1981,   30] loss:0.497
# Test set: Average loss: 0.2903
# [1982,   15] loss:0.507
# [1982,   30] loss:0.330
# Test set: Average loss: 0.3825
# [1983,   15] loss:0.511
# [1983,   30] loss:0.402
# Test set: Average loss: 0.4994
# [1984,   15] loss:0.481
# [1984,   30] loss:0.447
# Test set: Average loss: 0.5039
# [1985,   15] loss:0.578
# [1985,   30] loss:0.514
# Test set: Average loss: 0.4749
# [1986,   15] loss:0.532
# [1986,   30] loss:0.482
# Test set: Average loss: 0.5473
# [1987,   15] loss:0.454
# [1987,   30] loss:0.517
# Test set: Average loss: 0.2401
# [1988,   15] loss:0.374
# [1988,   30] loss:0.613
# Test set: Average loss: 0.2324
# [1989,   15] loss:0.523
# [1989,   30] loss:0.464
# Test set: Average loss: 0.3069
# [1990,   15] loss:0.415
# [1990,   30] loss:0.500
# Test set: Average loss: 0.5675
# [1991,   15] loss:0.536
# [1991,   30] loss:0.477
# Test set: Average loss: 0.4329
# [1992,   15] loss:0.477
# [1992,   30] loss:0.387
# Test set: Average loss: 0.3442
# [1993,   15] loss:0.493
# [1993,   30] loss:0.493
# Test set: Average loss: 0.2676
# [1994,   15] loss:0.421
# [1994,   30] loss:0.528
# Test set: Average loss: 0.4130
# [1995,   15] loss:0.499
# [1995,   30] loss:0.442
# Test set: Average loss: 0.4617
# [1996,   15] loss:0.481
# [1996,   30] loss:0.469
# Test set: Average loss: 0.3760
# [1997,   15] loss:0.445
# [1997,   30] loss:0.501
# Test set: Average loss: 0.3238
# [1998,   15] loss:0.424
# [1998,   30] loss:0.487
# Test set: Average loss: 0.4282
# [1999,   15] loss:0.474
# [1999,   30] loss:0.520
# Test set: Average loss: 0.2883
# [2000,   15] loss:0.383
# [2000,   30] loss:0.487
# Test set: Average loss: 0.3355
# Finished Training

# %%
device = torch.device(  'cpu')
test(NeuralNet(input_size=99, hidden_size=67, num_classes=2).to(device))
# Out:
# 测试集精度为：35%
# 测试集中不标准动作图片的预测精度为：38%
# 测试集中标准动作图片的预测精度为：32%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0       12   19
# 1       19    9

# %%
from torchsummary import summary
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess_contrast2.pkl')
model.to(device)
summary(model, input_size=(1,99))
print("测试精度如下：")
test(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 67]           6,700
#            Dropout-2                [-1, 1, 67]               0
#               ReLU-3                [-1, 1, 67]               0
#             Linear-4                 [-1, 1, 2]             136
# ================================================================
# Total params: 6,836
# Trainable params: 6,836
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.03
# ----------------------------------------------------------------
# 测试精度如下：
# 测试集精度为：61%
# 测试集中不标准动作图片的预测精度为：58%
# 测试集中标准动作图片的预测精度为：64%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0       18   13
# 1       10   18
