# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架提取后的图片数据集载入，划分训练集测试集'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited/train/goddess'
test_path ='/content/drive/MyDrive/yoga/annotated_image_evaluated_splited/test/goddess'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset = data1+data2+data3+data4+data5+data6+data7+data8
testset = torchvision.datasets.ImageFolder(root=test_path,transform=transform1) 
print(data1.class_to_idx)
BATCH_SIZE = 4
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# {'nonstandard': 0, 'standard': 1}

# %%
'''VGG19网络'''
import torchvision.models as models
import torch.nn as nn
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier[6] = nn.Linear(in_features=4096, out_features=2, bias=True)
'''for i in range(1,4):
  vgg19.classifier[i] = nn.Sequential()'''
print(vgg19)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_test1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_test1.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_test1.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_test1.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/trainloss_test1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/goddess/testloss_test1.csv',index=False)

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(vgg19.to(device),50,100)
# Out:
# [1,  100] loss:3.404
# [1,  200] loss:3.015
# Test set: Average loss: 0.8358
# [2,  100] loss:2.980
# [2,  200] loss:2.892
# Test set: Average loss: 0.7665
# [3,  100] loss:2.749
# [3,  200] loss:2.835
# Test set: Average loss: 0.7419
# [4,  100] loss:2.832
# [4,  200] loss:2.764
# Test set: Average loss: 0.7020
# [5,  100] loss:2.932
# [5,  200] loss:2.650
# Test set: Average loss: 0.7535
# [6,  100] loss:2.718
# [6,  200] loss:2.637
# Test set: Average loss: 0.7395
# [7,  100] loss:2.542
# [7,  200] loss:2.597
# Test set: Average loss: 0.7771
# [8,  100] loss:2.437
# [8,  200] loss:2.610
# Test set: Average loss: 0.7180
# [9,  100] loss:2.425
# [9,  200] loss:2.616
# Test set: Average loss: 0.8236
# [10,  100] loss:2.397
# [10,  200] loss:2.461
# Test set: Average loss: 0.7245
# [11,  100] loss:2.353
# [11,  200] loss:2.361
# Test set: Average loss: 0.6929
# [12,  100] loss:2.322
# [12,  200] loss:2.315
# Test set: Average loss: 0.7166
# [13,  100] loss:2.361
# [13,  200] loss:2.231
# Test set: Average loss: 0.7137
# [14,  100] loss:2.105
# [14,  200] loss:2.140
# Test set: Average loss: 0.7303
# [15,  100] loss:2.172
# [15,  200] loss:2.175
# Test set: Average loss: 0.7695
# [16,  100] loss:2.155
# [16,  200] loss:2.196
# Test set: Average loss: 0.7303
# [17,  100] loss:2.017
# [17,  200] loss:2.117
# Test set: Average loss: 0.7860
# [18,  100] loss:2.027
# [18,  200] loss:2.038
# Test set: Average loss: 0.7907
# [19,  100] loss:1.931
# [19,  200] loss:1.971
# Test set: Average loss: 0.6474
# [20,  100] loss:1.930
# [20,  200] loss:1.943
# Test set: Average loss: 0.7612
# [21,  100] loss:1.831
# [21,  200] loss:2.050
# Test set: Average loss: 0.7339
# [22,  100] loss:1.866
# [22,  200] loss:1.952
# Test set: Average loss: 0.8331
# [23,  100] loss:1.773
# [23,  200] loss:1.833
# Test set: Average loss: 0.8412
# [24,  100] loss:1.706
# [24,  200] loss:1.962
# Test set: Average loss: 0.8077
# [25,  100] loss:1.888
# [25,  200] loss:1.710
# Test set: Average loss: 0.8203
# [26,  100] loss:1.830
# [26,  200] loss:1.782
# Test set: Average loss: 0.8219
# [27,  100] loss:1.835
# [27,  200] loss:1.815
# Test set: Average loss: 0.8157
# [28,  100] loss:1.571
# [28,  200] loss:1.704
# Test set: Average loss: 0.8430
# [29,  100] loss:1.646
# [29,  200] loss:1.611
# Test set: Average loss: 0.6414
# [30,  100] loss:1.593
# [30,  200] loss:1.643
# Test set: Average loss: 0.7862
# [31,  100] loss:1.478
# [31,  200] loss:1.682
# Test set: Average loss: 0.7619
# [32,  100] loss:1.512
# [32,  200] loss:1.423
# Test set: Average loss: 0.8144
# [33,  100] loss:1.470
# [33,  200] loss:1.647
# Test set: Average loss: 0.8588
# [34,  100] loss:1.422
# [34,  200] loss:1.420
# Test set: Average loss: 0.7477
# [35,  100] loss:1.383
# [35,  200] loss:1.568
# Test set: Average loss: 0.7779
# [36,  100] loss:1.293
# [36,  200] loss:1.476
# Test set: Average loss: 0.8273
# [37,  100] loss:1.270
# [37,  200] loss:1.361
# Test set: Average loss: 0.8787
# [38,  100] loss:1.418
# [38,  200] loss:1.281
# Test set: Average loss: 0.8666
# [39,  100] loss:1.297
# [39,  200] loss:1.286
# Test set: Average loss: 0.8649
# [40,  100] loss:1.339
# [40,  200] loss:1.089
# Test set: Average loss: 0.8958
# [41,  100] loss:1.284
# [41,  200] loss:1.200
# Test set: Average loss: 0.8665
# [42,  100] loss:1.215
# [42,  200] loss:1.191
# Test set: Average loss: 0.9594
# [43,  100] loss:1.218
# [43,  200] loss:1.304
# Test set: Average loss: 0.9398
# [44,  100] loss:1.096
# [44,  200] loss:1.216
# Test set: Average loss: 0.9752
# [45,  100] loss:1.130
# [45,  200] loss:1.082
# Test set: Average loss: 0.8484
# [46,  100] loss:1.011
# [46,  200] loss:1.221
# Test set: Average loss: 0.9604
# [47,  100] loss:1.235
# [47,  200] loss:0.958
# Test set: Average loss: 1.0493
# [48,  100] loss:1.073
# [48,  200] loss:1.036
# Test set: Average loss: 0.8643
# [49,  100] loss:0.958
# [49,  200] loss:1.195
# Test set: Average loss: 0.9396
# [50,  100] loss:1.012
# [50,  200] loss:1.129
# Test set: Average loss: 1.0313
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:1.106
# [1,  200] loss:1.048
# Test set: Average loss: 1.0423
# [2,  100] loss:1.051
# [2,  200] loss:0.976
# Test set: Average loss: 1.0356
# [3,  100] loss:0.986
# [3,  200] loss:1.002
# Test set: Average loss: 1.0224
# [4,  100] loss:0.883
# [4,  200] loss:0.900
# Test set: Average loss: 1.1021
# [5,  100] loss:0.826
# [5,  200] loss:0.965
# Test set: Average loss: 0.9194
# [6,  100] loss:1.013
# [6,  200] loss:0.874
# Test set: Average loss: 1.0829
# [7,  100] loss:0.829
# [7,  200] loss:1.012
# Test set: Average loss: 1.0695
# [8,  100] loss:0.921
# [8,  200] loss:0.867
# Test set: Average loss: 0.9785
# [9,  100] loss:0.847
# [9,  200] loss:0.856
# Test set: Average loss: 1.1554
# [10,  100] loss:1.071
# [10,  200] loss:0.957
# Test set: Average loss: 1.1488
# [11,  100] loss:0.931
# [11,  200] loss:0.922
# Test set: Average loss: 1.0336
# [12,  100] loss:0.992
# [12,  200] loss:0.839
# Test set: Average loss: 1.2579
# [13,  100] loss:0.947
# [13,  200] loss:0.783
# Test set: Average loss: 1.1209
# [14,  100] loss:0.766
# [14,  200] loss:0.945
# Test set: Average loss: 1.0816
# [15,  100] loss:0.692
# [15,  200] loss:0.824
# Test set: Average loss: 1.1367
# [16,  100] loss:0.848
# [16,  200] loss:0.916
# Test set: Average loss: 1.0755
# [17,  100] loss:0.789
# [17,  200] loss:0.752
# Test set: Average loss: 1.0471
# [18,  100] loss:0.909
# [18,  200] loss:0.719
# Test set: Average loss: 1.0859
# [19,  100] loss:0.704
# [19,  200] loss:0.810
# Test set: Average loss: 1.1589
# [20,  100] loss:0.691
# [20,  200] loss:0.744
# Test set: Average loss: 1.1420
# [21,  100] loss:0.711
# [21,  200] loss:0.786
# Test set: Average loss: 1.2141
# [22,  100] loss:0.816
# [22,  200] loss:0.686
# Test set: Average loss: 1.2895
# [23,  100] loss:0.716
# [23,  200] loss:0.799
# Test set: Average loss: 1.3335
# [24,  100] loss:0.803
# [24,  200] loss:0.734
# Test set: Average loss: 1.2415
# [25,  100] loss:0.685
# [25,  200] loss:0.805
# Test set: Average loss: 1.1942
# [26,  100] loss:0.785
# [26,  200] loss:0.858
# Test set: Average loss: 1.1338
# [27,  100] loss:0.722
# [27,  200] loss:0.771
# Test set: Average loss: 1.1960
# [28,  100] loss:0.619
# [28,  200] loss:0.608
# Test set: Average loss: 1.2160
# [29,  100] loss:0.755
# [29,  200] loss:0.626
# Test set: Average loss: 1.2102
# [30,  100] loss:0.634
# [30,  200] loss:0.759
# Test set: Average loss: 1.3238
# [31,  100] loss:0.749
# [31,  200] loss:0.686
# Test set: Average loss: 1.4288
# [32,  100] loss:0.648
# [32,  200] loss:0.597
# Test set: Average loss: 1.0280
# [33,  100] loss:0.645
# [33,  200] loss:0.600
# Test set: Average loss: 1.3812
# [34,  100] loss:0.603
# [34,  200] loss:0.646
# Test set: Average loss: 1.2203
# [35,  100] loss:0.596
# [35,  200] loss:0.682
# Test set: Average loss: 1.2385
# [36,  100] loss:0.617
# [36,  200] loss:0.751
# Test set: Average loss: 1.4260
# [37,  100] loss:0.586
# [37,  200] loss:0.668
# Test set: Average loss: 1.0618
# [38,  100] loss:0.562
# [38,  200] loss:0.658
# Test set: Average loss: 1.2392
# [39,  100] loss:0.541
# [39,  200] loss:0.574
# Test set: Average loss: 1.3326
# [40,  100] loss:0.645
# [40,  200] loss:0.608
# Test set: Average loss: 1.3874
# [41,  100] loss:0.653
# [41,  200] loss:0.731
# Test set: Average loss: 1.2382
# [42,  100] loss:0.627
# [42,  200] loss:0.619
# Test set: Average loss: 1.3358
# [43,  100] loss:0.631
# [43,  200] loss:0.598
# Test set: Average loss: 1.2255
# [44,  100] loss:0.602
# [44,  200] loss:0.570
# Test set: Average loss: 1.2970
# [45,  100] loss:0.581
# [45,  200] loss:0.485
# Test set: Average loss: 1.3664
# [46,  100] loss:0.629
# [46,  200] loss:0.594
# Test set: Average loss: 1.3641
# [47,  100] loss:0.619
# [47,  200] loss:0.560
# Test set: Average loss: 1.4053
# [48,  100] loss:0.654
# [48,  200] loss:0.462
# Test set: Average loss: 1.3872
# [49,  100] loss:0.597
# [49,  200] loss:0.566
# Test set: Average loss: 1.4517
# [50,  100] loss:0.566
# [50,  200] loss:0.455
# Test set: Average loss: 1.4607
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.527
# [1,  200] loss:0.597
# Test set: Average loss: 1.2543
# [2,  100] loss:0.514
# [2,  200] loss:0.537
# Test set: Average loss: 1.3017
# [3,  100] loss:0.569
# [3,  200] loss:0.624
# Test set: Average loss: 1.5957
# [4,  100] loss:0.579
# [4,  200] loss:0.505
# Test set: Average loss: 1.3546
# [5,  100] loss:0.416
# [5,  200] loss:0.578
# Test set: Average loss: 1.3531
# [6,  100] loss:0.473
# [6,  200] loss:0.557
# Test set: Average loss: 1.3707
# [7,  100] loss:0.412
# [7,  200] loss:0.518
# Test set: Average loss: 1.3603
# [8,  100] loss:0.470
# [8,  200] loss:0.387
# Test set: Average loss: 1.4584
# [9,  100] loss:0.409
# [9,  200] loss:0.486
# Test set: Average loss: 1.5555
# [10,  100] loss:0.504
# [10,  200] loss:0.537
# Test set: Average loss: 1.4372
# [11,  100] loss:0.516
# [11,  200] loss:0.464
# Test set: Average loss: 1.3699
# [12,  100] loss:0.459
# [12,  200] loss:0.524
# Test set: Average loss: 1.3292
# [13,  100] loss:0.477
# [13,  200] loss:0.579
# Test set: Average loss: 1.3938
# [14,  100] loss:0.440
# [14,  200] loss:0.467
# Test set: Average loss: 1.4105
# [15,  100] loss:0.455
# [15,  200] loss:0.456
# Test set: Average loss: 1.5255
# [16,  100] loss:0.439
# [16,  200] loss:0.441
# Test set: Average loss: 1.5531
# [17,  100] loss:0.295
# [17,  200] loss:0.694
# Test set: Average loss: 1.3747
# [18,  100] loss:0.590
# [18,  200] loss:0.396
# Test set: Average loss: 1.4980
# [19,  100] loss:0.487
# [19,  200] loss:0.417
# Test set: Average loss: 1.3808
# [20,  100] loss:0.423
# [20,  200] loss:0.365
# Test set: Average loss: 1.5064
# [21,  100] loss:0.405
# [21,  200] loss:0.507
# Test set: Average loss: 1.5931
# [22,  100] loss:0.521
# [22,  200] loss:0.521
# Test set: Average loss: 1.4814
# [23,  100] loss:0.368
# [23,  200] loss:0.385
# Test set: Average loss: 1.4685
# [24,  100] loss:0.438
# [24,  200] loss:0.516
# Test set: Average loss: 1.7258
# [25,  100] loss:0.466
# [25,  200] loss:0.588
# Test set: Average loss: 1.5703
# [26,  100] loss:0.439
# [26,  200] loss:0.573
# Test set: Average loss: 1.4983
# [27,  100] loss:0.443
# [27,  200] loss:0.470
# Test set: Average loss: 1.5480
# [28,  100] loss:0.569
# [28,  200] loss:0.407
# Test set: Average loss: 1.4905
# [29,  100] loss:0.541
# [29,  200] loss:0.456
# Test set: Average loss: 1.5060
# [30,  100] loss:0.443
# [30,  200] loss:0.376
# Test set: Average loss: 1.4863
# [31,  100] loss:0.421
# [31,  200] loss:0.392
# Test set: Average loss: 1.7131
# [32,  100] loss:0.455
# [32,  200] loss:0.464
# Test set: Average loss: 1.5387
# [33,  100] loss:0.378
# [33,  200] loss:0.313
# Test set: Average loss: 1.5335
# [34,  100] loss:0.348
# [34,  200] loss:0.524
# Test set: Average loss: 1.7045
# [35,  100] loss:0.363
# [35,  200] loss:0.407
# Test set: Average loss: 1.4996
# [36,  100] loss:0.522
# [36,  200] loss:0.363
# Test set: Average loss: 1.6152
# [37,  100] loss:0.400
# [37,  200] loss:0.445
# Test set: Average loss: 1.5020
# [38,  100] loss:0.457
# [38,  200] loss:0.503
# Test set: Average loss: 1.5322
# [39,  100] loss:0.382
# [39,  200] loss:0.425
# Test set: Average loss: 1.4604
# [40,  100] loss:0.517
# [40,  200] loss:0.335
# Test set: Average loss: 1.6207
# [41,  100] loss:0.525
# [41,  200] loss:0.399
# Test set: Average loss: 1.6794
# [42,  100] loss:0.411
# [42,  200] loss:0.616
# Test set: Average loss: 1.6688
# [43,  100] loss:0.354
# [43,  200] loss:0.389
# Test set: Average loss: 1.5482
# [44,  100] loss:0.392
# [44,  200] loss:0.335
# Test set: Average loss: 1.6266
# [45,  100] loss:0.437
# [45,  200] loss:0.318
# Test set: Average loss: 1.7927
# [46,  100] loss:0.411
# [46,  200] loss:0.415
# Test set: Average loss: 1.7206
# [47,  100] loss:0.416
# [47,  200] loss:0.391
# Test set: Average loss: 1.6642
# [48,  100] loss:0.411
# [48,  200] loss:0.459
# Test set: Average loss: 1.5850
# [49,  100] loss:0.329
# [49,  200] loss:0.472
# Test set: Average loss: 1.5535
# [50,  100] loss:0.471
# [50,  200] loss:0.211
# Test set: Average loss: 1.6931
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.325
# [1,  200] loss:0.367
# Test set: Average loss: 1.3443
# [2,  100] loss:0.451
# [2,  200] loss:0.345
# Test set: Average loss: 1.5101
# [3,  100] loss:0.376
# [3,  200] loss:0.385
# Test set: Average loss: 1.3958
# [4,  100] loss:0.530
# [4,  200] loss:0.273
# Test set: Average loss: 1.5318
# [5,  100] loss:0.319
# [5,  200] loss:0.295
# Test set: Average loss: 1.5943
# [6,  100] loss:0.338
# [6,  200] loss:0.299
# Test set: Average loss: 1.6245
# [7,  100] loss:0.337
# [7,  200] loss:0.353
# Test set: Average loss: 1.5601
# [8,  100] loss:0.350
# [8,  200] loss:0.543
# Test set: Average loss: 1.7088
# [9,  100] loss:0.388
# [9,  200] loss:0.288
# Test set: Average loss: 1.7676
# [10,  100] loss:0.219
# [10,  200] loss:0.424
# Test set: Average loss: 1.7907
# [11,  100] loss:0.338
# [11,  200] loss:0.395
# Test set: Average loss: 1.5758
# [12,  100] loss:0.302
# [12,  200] loss:0.473
# Test set: Average loss: 1.5047
# [13,  100] loss:0.304
# [13,  200] loss:0.377
# Test set: Average loss: 1.7358
# [14,  100] loss:0.280
# [14,  200] loss:0.448
# Test set: Average loss: 1.6080
# [15,  100] loss:0.383
# [15,  200] loss:0.349
# Test set: Average loss: 1.7199
# [16,  100] loss:0.333
# [16,  200] loss:0.314
# Test set: Average loss: 1.7397
# [17,  100] loss:0.372
# [17,  200] loss:0.419
# Test set: Average loss: 1.6554
# [18,  100] loss:0.377
# [18,  200] loss:0.362
# Test set: Average loss: 1.7688
# [19,  100] loss:0.376
# [19,  200] loss:0.397
# Test set: Average loss: 1.7336
# [20,  100] loss:0.326
# [20,  200] loss:0.340
# Test set: Average loss: 1.8391
# [21,  100] loss:0.317
# [21,  200] loss:0.406
# Test set: Average loss: 1.6172
# [22,  100] loss:0.351
# [22,  200] loss:0.281
# Test set: Average loss: 1.7036
# [23,  100] loss:0.418
# [23,  200] loss:0.363
# Test set: Average loss: 1.5786
# [24,  100] loss:0.402
# [24,  200] loss:0.258
# Test set: Average loss: 1.6765
# [25,  100] loss:0.342
# [25,  200] loss:0.308
# Test set: Average loss: 1.7562
# [26,  100] loss:0.234
# [26,  200] loss:0.424
# Test set: Average loss: 1.6923
# [27,  100] loss:0.272
# [27,  200] loss:0.313
# Test set: Average loss: 1.7610
# [28,  100] loss:0.379
# [28,  200] loss:0.317
# Test set: Average loss: 1.7840
# [29,  100] loss:0.342
# [29,  200] loss:0.407
# Test set: Average loss: 1.7931
# [30,  100] loss:0.359
# [30,  200] loss:0.300
# Test set: Average loss: 1.7169
# [31,  100] loss:0.373
# [31,  200] loss:0.500
# Test set: Average loss: 1.7314
# [32,  100] loss:0.337
# [32,  200] loss:0.323
# Test set: Average loss: 1.7268
# [33,  100] loss:0.295
# [33,  200] loss:0.331
# Test set: Average loss: 1.7320
# [34,  100] loss:0.377
# [34,  200] loss:0.418
# Test set: Average loss: 1.7416
# [35,  100] loss:0.329
# [35,  200] loss:0.367
# Test set: Average loss: 1.8011
# [36,  100] loss:0.340
# [36,  200] loss:0.339
# Test set: Average loss: 1.8785
# [37,  100] loss:0.327
# [37,  200] loss:0.453
# Test set: Average loss: 1.8106
# [38,  100] loss:0.403
# [38,  200] loss:0.426
# Test set: Average loss: 1.6039
# [39,  100] loss:0.419
# [39,  200] loss:0.377
# Test set: Average loss: 1.7571
# [40,  100] loss:0.353
# [40,  200] loss:0.299
# Test set: Average loss: 1.7614
# [41,  100] loss:0.350
# [41,  200] loss:0.338
# Test set: Average loss: 1.8320
# [42,  100] loss:0.331
# [42,  200] loss:0.307
# Test set: Average loss: 1.6145
# [43,  100] loss:0.337
# [43,  200] loss:0.485
# Test set: Average loss: 1.7002
# [44,  100] loss:0.434
# [44,  200] loss:0.243
# Test set: Average loss: 1.7204
# [45,  100] loss:0.340
# [45,  200] loss:0.375
# Test set: Average loss: 2.1662
# [46,  100] loss:0.328
# [46,  200] loss:0.259
# Test set: Average loss: 1.7474
# [47,  100] loss:0.250
# [47,  200] loss:0.304
# Test set: Average loss: 1.7676
# [48,  100] loss:0.232
# [48,  200] loss:0.338
# Test set: Average loss: 1.6900
# [49,  100] loss:0.203
# [49,  200] loss:0.416
# Test set: Average loss: 1.8177
# [50,  100] loss:0.197
# [50,  200] loss:0.308
# Test set: Average loss: 1.7733
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.310
# [1,  200] loss:0.289
# Test set: Average loss: 1.8035
# [2,  100] loss:0.209
# [2,  200] loss:0.295
# Test set: Average loss: 1.6555
# [3,  100] loss:0.245
# [3,  200] loss:0.289
# Test set: Average loss: 1.9703
# [4,  100] loss:0.285
# [4,  200] loss:0.269
# Test set: Average loss: 2.0944
# [5,  100] loss:0.400
# [5,  200] loss:0.203
# Test set: Average loss: 1.9706
# [6,  100] loss:0.332
# [6,  200] loss:0.355
# Test set: Average loss: 1.8930
# [7,  100] loss:0.431
# [7,  200] loss:0.296
# Test set: Average loss: 1.5829
# [8,  100] loss:0.217
# [8,  200] loss:0.261
# Test set: Average loss: 1.9378
# [9,  100] loss:0.384
# [9,  200] loss:0.291
# Test set: Average loss: 1.8616
# [10,  100] loss:0.259
# [10,  200] loss:0.225
# Test set: Average loss: 1.8534
# [11,  100] loss:0.261
# [11,  200] loss:0.335
# Test set: Average loss: 1.8038
# [12,  100] loss:0.363
# [12,  200] loss:0.259
# Test set: Average loss: 1.9201
# [13,  100] loss:0.242
# [13,  200] loss:0.399
# Test set: Average loss: 1.9248
# [14,  100] loss:0.349
# [14,  200] loss:0.317
# Test set: Average loss: 1.9571
# [15,  100] loss:0.249
# [15,  200] loss:0.297
# Test set: Average loss: 1.8063
# [16,  100] loss:0.263
# [16,  200] loss:0.282
# Test set: Average loss: 1.8010
# [17,  100] loss:0.299
# [17,  200] loss:0.262
# Test set: Average loss: 2.0097
# [18,  100] loss:0.416
# [18,  200] loss:0.370
# Test set: Average loss: 1.7907
# [19,  100] loss:0.339
# [19,  200] loss:0.303
# Test set: Average loss: 1.8374
# [20,  100] loss:0.285
# [20,  200] loss:0.227
# Test set: Average loss: 2.1561
# [21,  100] loss:0.445
# [21,  200] loss:0.314
# Test set: Average loss: 1.6897
# [22,  100] loss:0.310
# [22,  200] loss:0.244
# Test set: Average loss: 1.9394
# [23,  100] loss:0.270
# [23,  200] loss:0.364
# Test set: Average loss: 1.8680
# [24,  100] loss:0.227
# [24,  200] loss:0.386
# Test set: Average loss: 1.9706
# [25,  100] loss:0.373
# [25,  200] loss:0.245
# Test set: Average loss: 2.0612
# [26,  100] loss:0.268
# [26,  200] loss:0.272
# Test set: Average loss: 1.7653
# [27,  100] loss:0.368
# [27,  200] loss:0.309
# Test set: Average loss: 1.9332
# [28,  100] loss:0.347
# [28,  200] loss:0.239
# Test set: Average loss: 1.8923
# [29,  100] loss:0.204
# [29,  200] loss:0.251
# Test set: Average loss: 1.7861
# [30,  100] loss:0.188
# [30,  200] loss:0.327
# Test set: Average loss: 2.0929
# [31,  100] loss:0.357
# [31,  200] loss:0.246
# Test set: Average loss: 1.7302
# [32,  100] loss:0.172
# [32,  200] loss:0.379
# Test set: Average loss: 1.6743
# [33,  100] loss:0.271
# [33,  200] loss:0.295
# Test set: Average loss: 1.8249
# [34,  100] loss:0.375
# [34,  200] loss:0.361
# Test set: Average loss: 1.8168
# [35,  100] loss:0.245
# [35,  200] loss:0.177
# Test set: Average loss: 1.8908
# [36,  100] loss:0.389
# [36,  200] loss:0.313
# Test set: Average loss: 2.0306
# [37,  100] loss:0.362
# [37,  200] loss:0.266
# Test set: Average loss: 1.7933
# [38,  100] loss:0.315
# [38,  200] loss:0.206
# Test set: Average loss: 1.7357
# [39,  100] loss:0.323
# [39,  200] loss:0.199
# Test set: Average loss: 1.7360
# [40,  100] loss:0.277
# [40,  200] loss:0.324
# Test set: Average loss: 1.9102
# [41,  100] loss:0.231
# [41,  200] loss:0.284
# Test set: Average loss: 1.9806
# [42,  100] loss:0.291
# [42,  200] loss:0.290
# Test set: Average loss: 1.8939
# [43,  100] loss:0.174
# [43,  200] loss:0.333
# Test set: Average loss: 1.7875
# [44,  100] loss:0.214
# [44,  200] loss:0.253
# Test set: Average loss: 1.6702
# [45,  100] loss:0.261
# [45,  200] loss:0.299
# Test set: Average loss: 1.8789
# [46,  100] loss:0.193
# [46,  200] loss:0.295
# Test set: Average loss: 1.9189
# [47,  100] loss:0.236
# [47,  200] loss:0.292
# Test set: Average loss: 1.8704
# [48,  100] loss:0.266
# [48,  200] loss:0.261
# Test set: Average loss: 2.1406
# [49,  100] loss:0.251
# [49,  200] loss:0.310
# Test set: Average loss: 1.9130
# [50,  100] loss:0.280
# [50,  200] loss:0.297
# Test set: Average loss: 1.8565
# Finished Training

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(vgg19.to(device))
# Out:
# 测试集精度为：62%
# 测试集中不标准动作图片的预测精度为：67%
# 测试集中标准动作图片的预测精度为：57%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     21   10
# 1.0     12   16

# %%
#训练200个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：72%
# 测试集中不标准动作图片的预测精度为：74%
# 测试集中标准动作图片的预测精度为：71%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     23    8
# 1.0      8   20

# %%
#训练250个epoch后的测试结果
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/goddess/YogaEvaNet_goddess1.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：71%
# 测试集中不标准动作图片的预测精度为：77%
# 测试集中标准动作图片的预测精度为：64%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     24    7
# 1.0     10   18
