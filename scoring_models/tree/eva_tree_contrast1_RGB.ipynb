# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''骨架提取后的图片数据集载入，划分训练集测试集'''
import torch
import torchvision
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
transform1 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform2 = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.RandomCrop([128, 128]), #随机裁剪
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform3 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomAffine(20),  #随机仿射变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform4 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomEqualize(0.9),  #概率直方图均衡
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform5 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.RandomHorizontalFlip(p=1),  #水平翻转
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform6 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(brightness=(0.5, 2)),  #亮度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform7 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(contrast=(0.5, 2)),  #对比度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
transform8 = transforms.Compose([
    transforms.Resize([128, 128]),
    transforms.ColorJitter(saturation=(0.5, 2)),  #饱和度在0.5-2之间随机取值进行变化
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5,.5,.5],std=[.5,.5,.5])
])
train_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/train/tree'
test_path ='/content/drive/MyDrive/yoga/yoga_pose_solo_evaluated_splited/test/tree'
data1 = torchvision.datasets.ImageFolder(root=train_path,transform=transform1) 
data2 = torchvision.datasets.ImageFolder(root=train_path,transform=transform2)
data3 = torchvision.datasets.ImageFolder(root=train_path,transform=transform3)
data4 = torchvision.datasets.ImageFolder(root=train_path,transform=transform4)
data5 = torchvision.datasets.ImageFolder(root=train_path,transform=transform5)
data6 = torchvision.datasets.ImageFolder(root=train_path,transform=transform6)
data7 = torchvision.datasets.ImageFolder(root=train_path,transform=transform7)
data8 = torchvision.datasets.ImageFolder(root=train_path,transform=transform8)
trainset = data1+data2+data3+data4+data5+data6+data7+data8
testset = torchvision.datasets.ImageFolder(root=test_path,transform=transform1) 
print(data1.class_to_idx)
BATCH_SIZE = 4
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# {'nonstandard': 0, 'standard': 1}

# %%
'''VGG19网络'''
import torchvision.models as models
import torch.nn as nn
vgg19 = models.vgg19(pretrained=True)
vgg19.classifier[6] = nn.Linear(in_features=4096, out_features=2, bias=True)
'''for i in range(6):
  vgg19.classifier[i] = nn.Sequential()'''
print(vgg19)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
'''定义训练和测试函数'''
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
def train_test(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    train_loss_list = []
    test_loss_list = []
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images, labels = data
              images, labels = images.to(device), labels.to(device)
              outputs = net(images)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/tree/trainloss_contrast1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/tree/testloss_contrast1.csv',index=False)
import pandas as pd
def test(net):
    correct = 0
    total = 0
    total_l = [0,0]
    correct_l = [0,0]
    pred_y = torch.tensor([]).to(device)
    Y_test = torch.tensor([]).to(device)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _,predicted = torch.max(outputs.data, 1)
            pred_y = torch.cat([pred_y,predicted])
            Y_test = torch.cat([Y_test,labels])
            total += labels.size(0)
            correct += (predicted == labels).sum().item() 
            for i in range(len(labels)):
                for l in range(2):
                    if labels[i] == torch.tensor(l).to(device):
                        total_l[l] += 1
                        correct_l[l] += (predicted[i] == labels[i]).sum().item()
    print('测试集精度为：%d%%'%(100 * correct / total))
    print('测试集中不标准动作图片的预测精度为：%d%%'%(100 * correct_l[0] / total_l[0]))
    print('测试集中标准动作图片的预测精度为：%d%%'%(100 * correct_l[1] / total_l[1]))
    print('混淆矩阵为：')
    print(pd.crosstab(Y_test.cpu(), pred_y.cpu()))

# %%
import torch.optim as optim
from PIL import ImageFile
import matplotlib.pyplot as plt
import pandas as pd
def train_test2(net, epoch_num, num_print):
    # 优化器
    criterion = nn.CrossEntropyLoss(reduction='sum')
    optimizer = optim.SGD(net.parameters(), lr = 0.0000004, momentum = 0.9)
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    df_trainloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/tree/trainloss_contrast1.csv')
    train_loss_list = df_trainloss['trainloss'].tolist()
    df_testloss = pd.read_csv('/content/drive/MyDrive/yoga/loss/tree/testloss_contrast1.csv')
    test_loss_list = df_testloss['testloss'].tolist()
    for epoch in range(epoch_num):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # 训练数据
            inputs1, labels = data
            inputs1, labels = inputs1.to(device), labels.to(device)
            # 权重参数清零
            optimizer.zero_grad()
            outputs = net(inputs1)  # 正向传播
            loss = criterion(outputs, labels)
            loss.backward()  #  反向传播
            optimizer.step()
            running_loss += loss.item()
            if i %num_print == (num_print-1):
                print('[%d, %4d] loss:%.3f'%(epoch + 1, i+1, running_loss / num_print))
                train_loss_list.append(running_loss/num_print)
                running_loss = 0.0
        test_loss = 0.0
        with torch.no_grad():
            for data in testloader:
              images1, labels = data
              images1, labels = images1.to(device), labels.to(device)
              outputs = net(images1)
              #_,predicted = torch.max(outputs.data, 1)
              #print(predicted, labels)
              loss = criterion(outputs, labels)
              test_loss += loss.item()
            test_loss /= len(testloader.dataset)
            print('Test set: Average loss: {:.4f}'.format(test_loss))
            test_loss_list.append(test_loss)
    x_train_loss=[]
    x_test_loss=[]
    for i in range(len(train_loss_list)):
        x_train_loss.append(i+1)
    for i in range(len(test_loss_list)):
        x_test_loss.append(i+1)
    plt.plot(x_train_loss,train_loss_list)
    plt.ylabel("train loss")
    plt.show()
    plt.plot(x_test_loss,test_loss_list)
    plt.ylabel("test loss")
    plt.show()
    print('Finished Training')
    torch.save(net, '/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
    df_trainloss = pd.DataFrame()
    df_trainloss['trainloss'] = train_loss_list
    df_trainloss.to_csv('/content/drive/MyDrive/yoga/loss/tree/trainloss_contrast1.csv',index=False)
    df_testloss = pd.DataFrame()
    df_testloss['testloss'] = test_loss_list
    df_testloss.to_csv('/content/drive/MyDrive/yoga/loss/tree/testloss_contrast1.csv',index=False)

# %%
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
test(vgg19.to(device))
# Out:
# 测试集精度为：50%
# 测试集中不标准动作图片的预测精度为：56%
# 测试集中标准动作图片的预测精度为：47%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     14   11
# 1.0     20   18

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
train_test(vgg19.to(device),50,100)
# Out:
# [1,  100] loss:2.993
# [1,  200] loss:2.854
# Test set: Average loss: 0.6748
# [2,  100] loss:2.842
# [2,  200] loss:2.724
# Test set: Average loss: 0.7017
# [3,  100] loss:2.509
# [3,  200] loss:2.375
# Test set: Average loss: 0.7712
# [4,  100] loss:2.395
# [4,  200] loss:2.457
# Test set: Average loss: 0.6963
# [5,  100] loss:2.433
# [5,  200] loss:2.356
# Test set: Average loss: 0.7914
# [6,  100] loss:2.278
# [6,  200] loss:2.391
# Test set: Average loss: 0.7492
# [7,  100] loss:2.283
# [7,  200] loss:2.142
# Test set: Average loss: 0.7243
# [8,  100] loss:2.282
# [8,  200] loss:2.172
# Test set: Average loss: 0.7247
# [9,  100] loss:2.137
# [9,  200] loss:2.102
# Test set: Average loss: 0.7615
# [10,  100] loss:2.105
# [10,  200] loss:2.020
# Test set: Average loss: 0.6991
# [11,  100] loss:2.094
# [11,  200] loss:2.090
# Test set: Average loss: 0.7964
# [12,  100] loss:1.955
# [12,  200] loss:2.004
# Test set: Average loss: 0.7777
# [13,  100] loss:1.849
# [13,  200] loss:2.009
# Test set: Average loss: 0.7577
# [14,  100] loss:2.005
# [14,  200] loss:1.921
# Test set: Average loss: 0.7628
# [15,  100] loss:1.879
# [15,  200] loss:1.910
# Test set: Average loss: 0.7583
# [16,  100] loss:1.791
# [16,  200] loss:1.926
# Test set: Average loss: 0.7942
# [17,  100] loss:1.693
# [17,  200] loss:1.813
# Test set: Average loss: 0.8466
# [18,  100] loss:1.728
# [18,  200] loss:1.847
# Test set: Average loss: 0.7102
# [19,  100] loss:1.752
# [19,  200] loss:1.592
# Test set: Average loss: 0.8594
# [20,  100] loss:1.688
# [20,  200] loss:1.695
# Test set: Average loss: 0.6665
# [21,  100] loss:1.779
# [21,  200] loss:1.617
# Test set: Average loss: 0.7356
# [22,  100] loss:1.602
# [22,  200] loss:1.672
# Test set: Average loss: 0.8026
# [23,  100] loss:1.541
# [23,  200] loss:1.734
# Test set: Average loss: 0.8378
# [24,  100] loss:1.590
# [24,  200] loss:1.540
# Test set: Average loss: 0.7938
# [25,  100] loss:1.480
# [25,  200] loss:1.556
# Test set: Average loss: 0.8985
# [26,  100] loss:1.541
# [26,  200] loss:1.390
# Test set: Average loss: 0.8383
# [27,  100] loss:1.558
# [27,  200] loss:1.432
# Test set: Average loss: 0.8906
# [28,  100] loss:1.501
# [28,  200] loss:1.357
# Test set: Average loss: 0.8607
# [29,  100] loss:1.367
# [29,  200] loss:1.439
# Test set: Average loss: 0.7959
# [30,  100] loss:1.308
# [30,  200] loss:1.337
# Test set: Average loss: 1.0364
# [31,  100] loss:1.362
# [31,  200] loss:1.400
# Test set: Average loss: 0.8384
# [32,  100] loss:1.264
# [32,  200] loss:1.329
# Test set: Average loss: 0.8614
# [33,  100] loss:1.383
# [33,  200] loss:1.170
# Test set: Average loss: 0.9874
# [34,  100] loss:1.281
# [34,  200] loss:1.271
# Test set: Average loss: 0.9773
# [35,  100] loss:1.093
# [35,  200] loss:1.110
# Test set: Average loss: 1.0281
# [36,  100] loss:1.163
# [36,  200] loss:1.084
# Test set: Average loss: 0.9430
# [37,  100] loss:1.310
# [37,  200] loss:1.221
# Test set: Average loss: 0.7880
# [38,  100] loss:1.177
# [38,  200] loss:1.080
# Test set: Average loss: 0.9926
# [39,  100] loss:1.260
# [39,  200] loss:1.201
# Test set: Average loss: 0.8698
# [40,  100] loss:1.180
# [40,  200] loss:1.165
# Test set: Average loss: 0.9179
# [41,  100] loss:1.090
# [41,  200] loss:1.176
# Test set: Average loss: 0.8935
# [42,  100] loss:1.231
# [42,  200] loss:1.238
# Test set: Average loss: 0.9282
# [43,  100] loss:1.215
# [43,  200] loss:1.156
# Test set: Average loss: 0.9886
# [44,  100] loss:0.972
# [44,  200] loss:1.073
# Test set: Average loss: 1.0612
# [45,  100] loss:1.047
# [45,  200] loss:0.956
# Test set: Average loss: 0.9753
# [46,  100] loss:1.096
# [46,  200] loss:0.957
# Test set: Average loss: 0.9634
# [47,  100] loss:1.007
# [47,  200] loss:0.999
# Test set: Average loss: 1.1221
# [48,  100] loss:1.157
# [48,  200] loss:0.921
# Test set: Average loss: 1.0252
# [49,  100] loss:0.945
# [49,  200] loss:1.010
# Test set: Average loss: 1.0672
# [50,  100] loss:0.974
# [50,  200] loss:1.009
# Test set: Average loss: 1.0681
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:1.016
# [1,  200] loss:0.963
# Test set: Average loss: 1.0839
# [2,  100] loss:1.012
# [2,  200] loss:1.003
# Test set: Average loss: 1.2200
# [3,  100] loss:0.952
# [3,  200] loss:0.995
# Test set: Average loss: 0.8989
# [4,  100] loss:0.867
# [4,  200] loss:0.950
# Test set: Average loss: 1.1642
# [5,  100] loss:0.989
# [5,  200] loss:0.970
# Test set: Average loss: 1.2294
# [6,  100] loss:0.884
# [6,  200] loss:0.991
# Test set: Average loss: 1.1352
# [7,  100] loss:0.907
# [7,  200] loss:0.887
# Test set: Average loss: 1.2686
# [8,  100] loss:0.829
# [8,  200] loss:0.781
# Test set: Average loss: 1.2218
# [9,  100] loss:0.840
# [9,  200] loss:0.869
# Test set: Average loss: 0.9894
# [10,  100] loss:0.833
# [10,  200] loss:0.877
# Test set: Average loss: 1.1143
# [11,  100] loss:0.994
# [11,  200] loss:0.743
# Test set: Average loss: 1.2406
# [12,  100] loss:0.733
# [12,  200] loss:0.862
# Test set: Average loss: 1.1459
# [13,  100] loss:0.776
# [13,  200] loss:0.900
# Test set: Average loss: 1.2227
# [14,  100] loss:0.857
# [14,  200] loss:0.833
# Test set: Average loss: 1.2490
# [15,  100] loss:0.784
# [15,  200] loss:0.817
# Test set: Average loss: 1.2214
# [16,  100] loss:0.812
# [16,  200] loss:0.694
# Test set: Average loss: 1.1410
# [17,  100] loss:0.957
# [17,  200] loss:0.929
# Test set: Average loss: 1.1238
# [18,  100] loss:0.837
# [18,  200] loss:0.753
# Test set: Average loss: 1.1283
# [19,  100] loss:0.847
# [19,  200] loss:0.775
# Test set: Average loss: 1.1202
# [20,  100] loss:0.894
# [20,  200] loss:0.687
# Test set: Average loss: 1.0659
# [21,  100] loss:0.710
# [21,  200] loss:0.762
# Test set: Average loss: 1.2518
# [22,  100] loss:0.822
# [22,  200] loss:0.840
# Test set: Average loss: 1.1877
# [23,  100] loss:0.765
# [23,  200] loss:0.757
# Test set: Average loss: 1.2147
# [24,  100] loss:0.716
# [24,  200] loss:0.702
# Test set: Average loss: 1.1490
# [25,  100] loss:0.836
# [25,  200] loss:0.662
# Test set: Average loss: 1.3553
# [26,  100] loss:0.736
# [26,  200] loss:0.591
# Test set: Average loss: 1.2744
# [27,  100] loss:0.746
# [27,  200] loss:0.615
# Test set: Average loss: 1.2519
# [28,  100] loss:0.705
# [28,  200] loss:0.769
# Test set: Average loss: 1.3039
# [29,  100] loss:0.870
# [29,  200] loss:0.669
# Test set: Average loss: 1.2599
# [30,  100] loss:0.642
# [30,  200] loss:0.888
# Test set: Average loss: 1.4244
# [31,  100] loss:0.800
# [31,  200] loss:0.641
# Test set: Average loss: 1.2302
# [32,  100] loss:0.737
# [32,  200] loss:0.765
# Test set: Average loss: 1.3198
# [33,  100] loss:0.812
# [33,  200] loss:0.609
# Test set: Average loss: 1.1797
# [34,  100] loss:0.682
# [34,  200] loss:0.606
# Test set: Average loss: 1.3066
# [35,  100] loss:0.570
# [35,  200] loss:0.555
# Test set: Average loss: 1.3859
# [36,  100] loss:0.577
# [36,  200] loss:0.515
# Test set: Average loss: 1.4445
# [37,  100] loss:0.722
# [37,  200] loss:0.597
# Test set: Average loss: 1.3790
# [38,  100] loss:0.655
# [38,  200] loss:0.751
# Test set: Average loss: 1.3841
# [39,  100] loss:0.724
# [39,  200] loss:0.697
# Test set: Average loss: 1.1822
# [40,  100] loss:0.457
# [40,  200] loss:0.669
# Test set: Average loss: 1.3745
# [41,  100] loss:0.815
# [41,  200] loss:0.557
# Test set: Average loss: 1.3710
# [42,  100] loss:0.589
# [42,  200] loss:0.697
# Test set: Average loss: 1.3562
# [43,  100] loss:0.638
# [43,  200] loss:0.737
# Test set: Average loss: 1.3327
# [44,  100] loss:0.549
# [44,  200] loss:0.646
# Test set: Average loss: 1.2448
# [45,  100] loss:0.561
# [45,  200] loss:0.623
# Test set: Average loss: 1.4155
# [46,  100] loss:0.647
# [46,  200] loss:0.605
# Test set: Average loss: 1.4696
# [47,  100] loss:0.610
# [47,  200] loss:0.528
# Test set: Average loss: 1.4634
# [48,  100] loss:0.513
# [48,  200] loss:0.737
# Test set: Average loss: 1.3648
# [49,  100] loss:0.666
# [49,  200] loss:0.634
# Test set: Average loss: 1.4953
# [50,  100] loss:0.535
# [50,  200] loss:0.630
# Test set: Average loss: 1.4396
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.584
# [1,  200] loss:0.670
# Test set: Average loss: 1.2456
# [2,  100] loss:0.635
# [2,  200] loss:0.685
# Test set: Average loss: 1.3090
# [3,  100] loss:0.647
# [3,  200] loss:0.608
# Test set: Average loss: 1.3531
# [4,  100] loss:0.501
# [4,  200] loss:0.587
# Test set: Average loss: 1.4083
# [5,  100] loss:0.581
# [5,  200] loss:0.585
# Test set: Average loss: 1.3458
# [6,  100] loss:0.494
# [6,  200] loss:0.646
# Test set: Average loss: 1.4898
# [7,  100] loss:0.692
# [7,  200] loss:0.526
# Test set: Average loss: 1.5109
# [8,  100] loss:0.536
# [8,  200] loss:0.593
# Test set: Average loss: 1.5114
# [9,  100] loss:0.592
# [9,  200] loss:0.648
# Test set: Average loss: 1.5207
# [10,  100] loss:0.529
# [10,  200] loss:0.681
# Test set: Average loss: 1.3544
# [11,  100] loss:0.551
# [11,  200] loss:0.587
# Test set: Average loss: 1.4018
# [12,  100] loss:0.721
# [12,  200] loss:0.668
# Test set: Average loss: 1.3804
# [13,  100] loss:0.619
# [13,  200] loss:0.592
# Test set: Average loss: 1.4493
# [14,  100] loss:0.473
# [14,  200] loss:0.584
# Test set: Average loss: 1.5152
# [15,  100] loss:0.603
# [15,  200] loss:0.542
# Test set: Average loss: 1.3839
# [16,  100] loss:0.496
# [16,  200] loss:0.503
# Test set: Average loss: 1.4630
# [17,  100] loss:0.494
# [17,  200] loss:0.748
# Test set: Average loss: 1.4256
# [18,  100] loss:0.486
# [18,  200] loss:0.701
# Test set: Average loss: 1.4336
# [19,  100] loss:0.524
# [19,  200] loss:0.612
# Test set: Average loss: 1.4139
# [20,  100] loss:0.617
# [20,  200] loss:0.562
# Test set: Average loss: 1.4954
# [21,  100] loss:0.614
# [21,  200] loss:0.558
# Test set: Average loss: 1.4214
# [22,  100] loss:0.574
# [22,  200] loss:0.693
# Test set: Average loss: 1.3413
# [23,  100] loss:0.552
# [23,  200] loss:0.616
# Test set: Average loss: 1.4720
# [24,  100] loss:0.417
# [24,  200] loss:0.604
# Test set: Average loss: 1.5410
# [25,  100] loss:0.497
# [25,  200] loss:0.513
# Test set: Average loss: 1.3624
# [26,  100] loss:0.574
# [26,  200] loss:0.631
# Test set: Average loss: 1.5838
# [27,  100] loss:0.574
# [27,  200] loss:0.479
# Test set: Average loss: 1.6201
# [28,  100] loss:0.547
# [28,  200] loss:0.601
# Test set: Average loss: 1.6388
# [29,  100] loss:0.517
# [29,  200] loss:0.501
# Test set: Average loss: 1.6634
# [30,  100] loss:0.512
# [30,  200] loss:0.505
# Test set: Average loss: 1.4691
# [31,  100] loss:0.576
# [31,  200] loss:0.531
# Test set: Average loss: 1.5721
# [32,  100] loss:0.468
# [32,  200] loss:0.680
# Test set: Average loss: 1.4766
# [33,  100] loss:0.476
# [33,  200] loss:0.475
# Test set: Average loss: 1.6537
# [34,  100] loss:0.589
# [34,  200] loss:0.494
# Test set: Average loss: 1.3733
# [35,  100] loss:0.493
# [35,  200] loss:0.399
# Test set: Average loss: 1.7217
# [36,  100] loss:0.435
# [36,  200] loss:0.546
# Test set: Average loss: 1.5818
# [37,  100] loss:0.704
# [37,  200] loss:0.414
# Test set: Average loss: 1.5100
# [38,  100] loss:0.434
# [38,  200] loss:0.534
# Test set: Average loss: 1.7264
# [39,  100] loss:0.505
# [39,  200] loss:0.606
# Test set: Average loss: 1.6890
# [40,  100] loss:0.482
# [40,  200] loss:0.444
# Test set: Average loss: 1.4788
# [41,  100] loss:0.547
# [41,  200] loss:0.596
# Test set: Average loss: 1.6014
# [42,  100] loss:0.443
# [42,  200] loss:0.547
# Test set: Average loss: 1.4982
# [43,  100] loss:0.413
# [43,  200] loss:0.460
# Test set: Average loss: 1.4763
# [44,  100] loss:0.667
# [44,  200] loss:0.588
# Test set: Average loss: 1.3574
# [45,  100] loss:0.414
# [45,  200] loss:0.486
# Test set: Average loss: 1.5749
# [46,  100] loss:0.459
# [46,  200] loss:0.536
# Test set: Average loss: 1.4262
# [47,  100] loss:0.532
# [47,  200] loss:0.455
# Test set: Average loss: 1.6521
# [48,  100] loss:0.448
# [48,  200] loss:0.452
# Test set: Average loss: 1.6877
# [49,  100] loss:0.510
# [49,  200] loss:0.503
# Test set: Average loss: 1.6620
# [50,  100] loss:0.471
# [50,  200] loss:0.465
# Test set: Average loss: 1.5939
# Finished Training

# %%
import os
from torch import nn
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
train_test2(model.to(device),50,100)
# Out:
# [1,  100] loss:0.401
# [1,  200] loss:0.529
# Test set: Average loss: 1.5133
# [2,  100] loss:0.415
# [2,  200] loss:0.485
# Test set: Average loss: 1.5274
# [3,  100] loss:0.467
# [3,  200] loss:0.528
# Test set: Average loss: 1.5902
# [4,  100] loss:0.607
# [4,  200] loss:0.468
# Test set: Average loss: 1.6560
# [5,  100] loss:0.562
# [5,  200] loss:0.476
# Test set: Average loss: 1.5183
# [6,  100] loss:0.536
# [6,  200] loss:0.387
# Test set: Average loss: 1.6659
# [7,  100] loss:0.605
# [7,  200] loss:0.482
# Test set: Average loss: 1.5228
# [8,  100] loss:0.456
# [8,  200] loss:0.592
# Test set: Average loss: 1.7573
# [9,  100] loss:0.480
# [9,  200] loss:0.511
# Test set: Average loss: 1.6985
# [10,  100] loss:0.636
# [10,  200] loss:0.422
# Test set: Average loss: 1.5801
# [11,  100] loss:0.521
# [11,  200] loss:0.494
# Test set: Average loss: 1.6865
# [12,  100] loss:0.401
# [12,  200] loss:0.526
# Test set: Average loss: 1.5440
# [13,  100] loss:0.444
# [13,  200] loss:0.479
# Test set: Average loss: 1.6598
# [14,  100] loss:0.465
# [14,  200] loss:0.433
# Test set: Average loss: 1.6679
# [15,  100] loss:0.475
# [15,  200] loss:0.352
# Test set: Average loss: 1.5243
# [16,  100] loss:0.619
# [16,  200] loss:0.473

# %%
#训练150个epoch的测试精度
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu')
model = torch.load('/content/drive/MyDrive/yoga/models/tree/YogaEvaNet_tree_contrast1.pkl')
model.to(device)
print("测试精度如下：")
test(model)
# Out:
# 测试精度如下：
# 测试集精度为：65%
# 测试集中不标准动作图片的预测精度为：56%
# 测试集中标准动作图片的预测精度为：71%
# 混淆矩阵为：
# col_0  0.0  1.0
# row_0
# 0.0     14   11
# 1.0     11   27
